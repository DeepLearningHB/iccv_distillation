# %%
import os
import sys
import torch
import torch.nn as nn
import torch.nn.functional as F
from models import model_dict
from dataset.cifar100 import *
import torchinfo
from models.resnet import ResNet
import torch.optim as optim
import time
import argparse
import matplotlib.pyplot as plt
from munch import Munch
from torchsummary import summary

# %%
opt = {'model_t': 'resnet32x4',
       'model_s': 'resnet8x4',
       'path_t': './save/models/resnet32x4_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)

MAX_CHANNEL = 310

# %%
train_batch_size = 128
test_batch_size = 100
n_cls = 100
num_workers = 1
total_epoch = 240
learning_rate = 0.05
lr_decay_epoch = [150, 180, 210]
lr_decay_rate = 0.1
weight_decay = 5e-4
momentum = 0.9
print_freq = 100

balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

path_t = opt.path_t
trial = 0
r = 1
a = 0
b = 1
p = 1
d = 1
kd_T = 4
fm_beta = 1e-2
fit_alpha = 0.2

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller
optimizer = optim.SGD(trainable_models.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay)

best_accuracy = -1
best_ensemble_acc = -1
# Out:
# 1 feature: torch.Size([1, 32, 32, 32])
# 2 feature: torch.Size([1, 64, 32, 32])
# 3 feature: torch.Size([1, 128, 16, 16])
# 4 feature: torch.Size([1, 256, 8, 8])
# 5 feature: torch.Size([1, 256])
# final feature: torch.Size([1, 100])

# %%
print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)
# Out:
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            864
# ├─BatchNorm2d: 1-2                       64
# ├─ReLU: 1-3                              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  18,432
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  36,864
# |    |    └─BatchNorm2d: 3-5             128
# |    |    └─Sequential: 3-6              2,176
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-7                  36,864
# |    |    └─BatchNorm2d: 3-8             128
# |    |    └─ReLU: 3-9                    --
# |    |    └─Conv2d: 3-10                 36,864
# |    |    └─BatchNorm2d: 3-11            128
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-12                 36,864
# |    |    └─BatchNorm2d: 3-13            128
# |    |    └─ReLU: 3-14                   --
# |    |    └─Conv2d: 3-15                 36,864
# |    |    └─BatchNorm2d: 3-16            128
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-17                 36,864
# |    |    └─BatchNorm2d: 3-18            128
# |    |    └─ReLU: 3-19                   --
# |    |    └─Conv2d: 3-20                 36,864
# |    |    └─BatchNorm2d: 3-21            128
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-22                 36,864
# |    |    └─BatchNorm2d: 3-23            128
# |    |    └─ReLU: 3-24                   --
# |    |    └─Conv2d: 3-25                 36,864
# |    |    └─BatchNorm2d: 3-26            128
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-27                 73,728
# |    |    └─BatchNorm2d: 3-28            256
# |    |    └─ReLU: 3-29                   --
# |    |    └─Conv2d: 3-30                 147,456
# |    |    └─BatchNorm2d: 3-31            256
# |    |    └─Sequential: 3-32             8,448
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-33                 147,456
# |    |    └─BatchNorm2d: 3-34            256
# |    |    └─ReLU: 3-35                   --
# |    |    └─Conv2d: 3-36                 147,456
# |    |    └─BatchNorm2d: 3-37            256
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-38                 147,456
# |    |    └─BatchNorm2d: 3-39            256
# |    |    └─ReLU: 3-40                   --
# |    |    └─Conv2d: 3-41                 147,456
# |    |    └─BatchNorm2d: 3-42            256
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-43                 147,456
# |    |    └─BatchNorm2d: 3-44            256
# |    |    └─ReLU: 3-45                   --
# |    |    └─Conv2d: 3-46                 147,456
# |    |    └─BatchNorm2d: 3-47            256
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-48                 147,456
# |    |    └─BatchNorm2d: 3-49            256
# |    |    └─ReLU: 3-50                   --
# |    |    └─Conv2d: 3-51                 147,456
# |    |    └─BatchNorm2d: 3-52            256
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-53                 294,912
# |    |    └─BatchNorm2d: 3-54            512
# |    |    └─ReLU: 3-55                   --
# |    |    └─Conv2d: 3-56                 589,824
# |    |    └─BatchNorm2d: 3-57            512
# |    |    └─Sequential: 3-58             33,280
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-59                 589,824
# |    |    └─BatchNorm2d: 3-60            512
# |    |    └─ReLU: 3-61                   --
# |    |    └─Conv2d: 3-62                 589,824
# |    |    └─BatchNorm2d: 3-63            512
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-64                 589,824
# |    |    └─BatchNorm2d: 3-65            512
# |    |    └─ReLU: 3-66                   --
# |    |    └─Conv2d: 3-67                 589,824
# |    |    └─BatchNorm2d: 3-68            512
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-69                 589,824
# |    |    └─BatchNorm2d: 3-70            512
# |    |    └─ReLU: 3-71                   --
# |    |    └─Conv2d: 3-72                 589,824
# |    |    └─BatchNorm2d: 3-73            512
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-74                 589,824
# |    |    └─BatchNorm2d: 3-75            512
# |    |    └─ReLU: 3-76                   --
# |    |    └─Conv2d: 3-77                 589,824
# |    |    └─BatchNorm2d: 3-78            512
# ├─AvgPool2d: 1-7                         --
# ├─Linear: 1-8                            25,700
# =================================================================
# Total params: 7,433,860
# Trainable params: 7,433,860
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            864
# ├─BatchNorm2d: 1-2                       64
# ├─ReLU: 1-3                              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  18,432
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  36,864
# |    |    └─BatchNorm2d: 3-5             128
# |    |    └─Sequential: 3-6              2,176
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-7                  73,728
# |    |    └─BatchNorm2d: 3-8             256
# |    |    └─ReLU: 3-9                    --
# |    |    └─Conv2d: 3-10                 147,456
# |    |    └─BatchNorm2d: 3-11            256
# |    |    └─Sequential: 3-12             8,448
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-13                 294,912
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─ReLU: 3-15                   --
# |    |    └─Conv2d: 3-16                 589,824
# |    |    └─BatchNorm2d: 3-17            512
# |    |    └─Sequential: 3-18             33,280
# ├─AvgPool2d: 1-7                         --
# ├─Linear: 1-8                            25,700
# =================================================================
# Total params: 1,233,540
# Trainable params: 1,233,540
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 33,586
# |    |    └─SepConv: 3-2                 63,762
# |    |    └─SepConv: 3-3                 124,114
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       25,700
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 63,762
# |    |    └─SepConv: 3-6                 124,114
# |    |    └─SepConv: 3-7                 164,946
# |    |    └─AvgPool2d: 3-8               --
# |    └─Linear: 2-4                       25,700
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-9                 124,114
# |    |    └─SepConv: 3-10                164,946
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-6                       25,700
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-12                164,946
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-8                       25,700
# ├─FinalClassifier: 1-5                   --
# |    └─Linear: 2-9                       25,700
# =================================================================
# Total params: 1,156,790
# Trainable params: 1,156,790
# Non-trainable params: 0
# =================================================================

# %%
params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              33,586
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              63,762
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              124,114
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            25,700
# =================================================================
# Total params: 247,162
# Trainable params: 247,162
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              63,762
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              124,114
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              164,946
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            25,700
# =================================================================
# Total params: 378,522
# Trainable params: 378,522
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              124,114
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              164,946
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            25,700
# =================================================================
# Total params: 314,760
# Trainable params: 314,760
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              164,946
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            25,700
# =================================================================
# Total params: 190,646
# Trainable params: 190,646
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            25,700
# =================================================================
# Total params: 25,700
# Trainable params: 25,700
# Non-trainable params: 0
# =================================================================

# %%
print("ResNet32x4 - ResNet8x4")
model_t_params = 7433860
model_s_params = 1233540
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
model_s_ensemble1 = 864+64 + conv_distiller1
model_s_ensemble2 = 18432+128+36864+128+2176 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 73728+256+147456+256+8448 + conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 294912+512+589824+512+33280 + conv_distiller4 + model_s_ensemble3
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# ResNet32x4 - ResNet8x4
# Teacher model: 7433860 (100.000%)
# Student model: 1233540 (16.594%)
# Ensemble 1: 248090 (3.337%)
# Ensemble 2: 684340 (9.206%)
# Ensemble 3: 1229244 (16.536%)
# Ensemble 4: 2338930 (31.463%)
# Final Ensemble: 2390330 (32.155%)

# %%
opt = {'model_t': 'resnet110',
       'model_s': 'resnet32',
       'path_t': './save/models/resnet110_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 400

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)


balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 16, 32, 32])
# 2 feature: torch.Size([1, 16, 32, 32])
# 3 feature: torch.Size([1, 32, 16, 16])
# 4 feature: torch.Size([1, 64, 8, 8])
# 5 feature: torch.Size([1, 64])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─BatchNorm2d: 1-2                       32
# ├─ReLU: 1-3                              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  2,304
# |    |    └─BatchNorm2d: 3-2             32
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  2,304
# |    |    └─BatchNorm2d: 3-5             32
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  2,304
# |    |    └─BatchNorm2d: 3-7             32
# |    |    └─ReLU: 3-8                    --
# |    |    └─Conv2d: 3-9                  2,304
# |    |    └─BatchNorm2d: 3-10            32
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 2,304
# |    |    └─BatchNorm2d: 3-12            32
# |    |    └─ReLU: 3-13                   --
# |    |    └─Conv2d: 3-14                 2,304
# |    |    └─BatchNorm2d: 3-15            32
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 2,304
# |    |    └─BatchNorm2d: 3-17            32
# |    |    └─ReLU: 3-18                   --
# |    |    └─Conv2d: 3-19                 2,304
# |    |    └─BatchNorm2d: 3-20            32
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 2,304
# |    |    └─BatchNorm2d: 3-22            32
# |    |    └─ReLU: 3-23                   --
# |    |    └─Conv2d: 3-24                 2,304
# |    |    └─BatchNorm2d: 3-25            32
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 2,304
# |    |    └─BatchNorm2d: 3-27            32
# |    |    └─ReLU: 3-28                   --
# |    |    └─Conv2d: 3-29                 2,304
# |    |    └─BatchNorm2d: 3-30            32
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 2,304
# |    |    └─BatchNorm2d: 3-32            32
# |    |    └─ReLU: 3-33                   --
# |    |    └─Conv2d: 3-34                 2,304
# |    |    └─BatchNorm2d: 3-35            32
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 2,304
# |    |    └─BatchNorm2d: 3-37            32
# |    |    └─ReLU: 3-38                   --
# |    |    └─Conv2d: 3-39                 2,304
# |    |    └─BatchNorm2d: 3-40            32
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 2,304
# |    |    └─BatchNorm2d: 3-42            32
# |    |    └─ReLU: 3-43                   --
# |    |    └─Conv2d: 3-44                 2,304
# |    |    └─BatchNorm2d: 3-45            32
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-46                 2,304
# |    |    └─BatchNorm2d: 3-47            32
# |    |    └─ReLU: 3-48                   --
# |    |    └─Conv2d: 3-49                 2,304
# |    |    └─BatchNorm2d: 3-50            32
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-51                 2,304
# |    |    └─BatchNorm2d: 3-52            32
# |    |    └─ReLU: 3-53                   --
# |    |    └─Conv2d: 3-54                 2,304
# |    |    └─BatchNorm2d: 3-55            32
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-56                 2,304
# |    |    └─BatchNorm2d: 3-57            32
# |    |    └─ReLU: 3-58                   --
# |    |    └─Conv2d: 3-59                 2,304
# |    |    └─BatchNorm2d: 3-60            32
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-61                 2,304
# |    |    └─BatchNorm2d: 3-62            32
# |    |    └─ReLU: 3-63                   --
# |    |    └─Conv2d: 3-64                 2,304
# |    |    └─BatchNorm2d: 3-65            32
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-66                 2,304
# |    |    └─BatchNorm2d: 3-67            32
# |    |    └─ReLU: 3-68                   --
# |    |    └─Conv2d: 3-69                 2,304
# |    |    └─BatchNorm2d: 3-70            32
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-71                 2,304
# |    |    └─BatchNorm2d: 3-72            32
# |    |    └─ReLU: 3-73                   --
# |    |    └─Conv2d: 3-74                 2,304
# |    |    └─BatchNorm2d: 3-75            32
# |    └─BasicBlock: 2-16                  --
# |    |    └─Conv2d: 3-76                 2,304
# |    |    └─BatchNorm2d: 3-77            32
# |    |    └─ReLU: 3-78                   --
# |    |    └─Conv2d: 3-79                 2,304
# |    |    └─BatchNorm2d: 3-80            32
# |    └─BasicBlock: 2-17                  --
# |    |    └─Conv2d: 3-81                 2,304
# |    |    └─BatchNorm2d: 3-82            32
# |    |    └─ReLU: 3-83                   --
# |    |    └─Conv2d: 3-84                 2,304
# |    |    └─BatchNorm2d: 3-85            32
# |    └─BasicBlock: 2-18                  --
# |    |    └─Conv2d: 3-86                 2,304
# |    |    └─BatchNorm2d: 3-87            32
# |    |    └─ReLU: 3-88                   --
# |    |    └─Conv2d: 3-89                 2,304
# |    |    └─BatchNorm2d: 3-90            32
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-19                  --
# |    |    └─Conv2d: 3-91                 4,608
# |    |    └─BatchNorm2d: 3-92            64
# |    |    └─ReLU: 3-93                   --
# |    |    └─Conv2d: 3-94                 9,216
# |    |    └─BatchNorm2d: 3-95            64
# |    |    └─Sequential: 3-96             576
# |    └─BasicBlock: 2-20                  --
# |    |    └─Conv2d: 3-97                 9,216
# |    |    └─BatchNorm2d: 3-98            64
# |    |    └─ReLU: 3-99                   --
# |    |    └─Conv2d: 3-100                9,216
# |    |    └─BatchNorm2d: 3-101           64
# |    └─BasicBlock: 2-21                  --
# |    |    └─Conv2d: 3-102                9,216
# |    |    └─BatchNorm2d: 3-103           64
# |    |    └─ReLU: 3-104                  --
# |    |    └─Conv2d: 3-105                9,216
# |    |    └─BatchNorm2d: 3-106           64
# |    └─BasicBlock: 2-22                  --
# |    |    └─Conv2d: 3-107                9,216
# |    |    └─BatchNorm2d: 3-108           64
# |    |    └─ReLU: 3-109                  --
# |    |    └─Conv2d: 3-110                9,216
# |    |    └─BatchNorm2d: 3-111           64
# |    └─BasicBlock: 2-23                  --
# |    |    └─Conv2d: 3-112                9,216
# |    |    └─BatchNorm2d: 3-113           64
# |    |    └─ReLU: 3-114                  --
# |    |    └─Conv2d: 3-115                9,216
# |    |    └─BatchNorm2d: 3-116           64
# |    └─BasicBlock: 2-24                  --
# |    |    └─Conv2d: 3-117                9,216
# |    |    └─BatchNorm2d: 3-118           64
# |    |    └─ReLU: 3-119                  --
# |    |    └─Conv2d: 3-120                9,216
# |    |    └─BatchNorm2d: 3-121           64
# |    └─BasicBlock: 2-25                  --
# |    |    └─Conv2d: 3-122                9,216
# |    |    └─BatchNorm2d: 3-123           64
# |    |    └─ReLU: 3-124                  --
# |    |    └─Conv2d: 3-125                9,216
# |    |    └─BatchNorm2d: 3-126           64
# |    └─BasicBlock: 2-26                  --
# |    |    └─Conv2d: 3-127                9,216
# |    |    └─BatchNorm2d: 3-128           64
# |    |    └─ReLU: 3-129                  --
# |    |    └─Conv2d: 3-130                9,216
# |    |    └─BatchNorm2d: 3-131           64
# |    └─BasicBlock: 2-27                  --
# |    |    └─Conv2d: 3-132                9,216
# |    |    └─BatchNorm2d: 3-133           64
# |    |    └─ReLU: 3-134                  --
# |    |    └─Conv2d: 3-135                9,216
# |    |    └─BatchNorm2d: 3-136           64
# |    └─BasicBlock: 2-28                  --
# |    |    └─Conv2d: 3-137                9,216
# |    |    └─BatchNorm2d: 3-138           64
# |    |    └─ReLU: 3-139                  --
# |    |    └─Conv2d: 3-140                9,216
# |    |    └─BatchNorm2d: 3-141           64
# |    └─BasicBlock: 2-29                  --
# |    |    └─Conv2d: 3-142                9,216
# |    |    └─BatchNorm2d: 3-143           64
# |    |    └─ReLU: 3-144                  --
# |    |    └─Conv2d: 3-145                9,216
# |    |    └─BatchNorm2d: 3-146           64
# |    └─BasicBlock: 2-30                  --
# |    |    └─Conv2d: 3-147                9,216
# |    |    └─BatchNorm2d: 3-148           64
# |    |    └─ReLU: 3-149                  --
# |    |    └─Conv2d: 3-150                9,216
# |    |    └─BatchNorm2d: 3-151           64
# |    └─BasicBlock: 2-31                  --
# |    |    └─Conv2d: 3-152                9,216
# |    |    └─BatchNorm2d: 3-153           64
# |    |    └─ReLU: 3-154                  --
# |    |    └─Conv2d: 3-155                9,216
# |    |    └─BatchNorm2d: 3-156           64
# |    └─BasicBlock: 2-32                  --
# |    |    └─Conv2d: 3-157                9,216
# |    |    └─BatchNorm2d: 3-158           64
# |    |    └─ReLU: 3-159                  --
# |    |    └─Conv2d: 3-160                9,216
# |    |    └─BatchNorm2d: 3-161           64
# |    └─BasicBlock: 2-33                  --
# |    |    └─Conv2d: 3-162                9,216
# |    |    └─BatchNorm2d: 3-163           64
# |    |    └─ReLU: 3-164                  --
# |    |    └─Conv2d: 3-165                9,216
# |    |    └─BatchNorm2d: 3-166           64
# |    └─BasicBlock: 2-34                  --
# |    |    └─Conv2d: 3-167                9,216
# |    |    └─BatchNorm2d: 3-168           64
# |    |    └─ReLU: 3-169                  --
# |    |    └─Conv2d: 3-170                9,216
# |    |    └─BatchNorm2d: 3-171           64
# |    └─BasicBlock: 2-35                  --
# |    |    └─Conv2d: 3-172                9,216
# |    |    └─BatchNorm2d: 3-173           64
# |    |    └─ReLU: 3-174                  --
# |    |    └─Conv2d: 3-175                9,216
# |    |    └─BatchNorm2d: 3-176           64
# |    └─BasicBlock: 2-36                  --
# |    |    └─Conv2d: 3-177                9,216
# |    |    └─BatchNorm2d: 3-178           64
# |    |    └─ReLU: 3-179                  --
# |    |    └─Conv2d: 3-180                9,216
# |    |    └─BatchNorm2d: 3-181           64
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-37                  --
# |    |    └─Conv2d: 3-182                18,432
# |    |    └─BatchNorm2d: 3-183           128
# |    |    └─ReLU: 3-184                  --
# |    |    └─Conv2d: 3-185                36,864
# |    |    └─BatchNorm2d: 3-186           128
# |    |    └─Sequential: 3-187            2,176
# |    └─BasicBlock: 2-38                  --
# |    |    └─Conv2d: 3-188                36,864
# |    |    └─BatchNorm2d: 3-189           128
# |    |    └─ReLU: 3-190                  --
# |    |    └─Conv2d: 3-191                36,864
# |    |    └─BatchNorm2d: 3-192           128
# |    └─BasicBlock: 2-39                  --
# |    |    └─Conv2d: 3-193                36,864
# |    |    └─BatchNorm2d: 3-194           128
# |    |    └─ReLU: 3-195                  --
# |    |    └─Conv2d: 3-196                36,864
# |    |    └─BatchNorm2d: 3-197           128
# |    └─BasicBlock: 2-40                  --
# |    |    └─Conv2d: 3-198                36,864
# |    |    └─BatchNorm2d: 3-199           128
# |    |    └─ReLU: 3-200                  --
# |    |    └─Conv2d: 3-201                36,864
# |    |    └─BatchNorm2d: 3-202           128
# |    └─BasicBlock: 2-41                  --
# |    |    └─Conv2d: 3-203                36,864
# |    |    └─BatchNorm2d: 3-204           128
# |    |    └─ReLU: 3-205                  --
# |    |    └─Conv2d: 3-206                36,864
# |    |    └─BatchNorm2d: 3-207           128
# |    └─BasicBlock: 2-42                  --
# |    |    └─Conv2d: 3-208                36,864
# |    |    └─BatchNorm2d: 3-209           128
# |    |    └─ReLU: 3-210                  --
# |    |    └─Conv2d: 3-211                36,864
# |    |    └─BatchNorm2d: 3-212           128
# |    └─BasicBlock: 2-43                  --
# |    |    └─Conv2d: 3-213                36,864
# |    |    └─BatchNorm2d: 3-214           128
# |    |    └─ReLU: 3-215                  --
# |    |    └─Conv2d: 3-216                36,864
# |    |    └─BatchNorm2d: 3-217           128
# |    └─BasicBlock: 2-44                  --
# |    |    └─Conv2d: 3-218                36,864
# |    |    └─BatchNorm2d: 3-219           128
# |    |    └─ReLU: 3-220                  --
# |    |    └─Conv2d: 3-221                36,864
# |    |    └─BatchNorm2d: 3-222           128
# |    └─BasicBlock: 2-45                  --
# |    |    └─Conv2d: 3-223                36,864
# |    |    └─BatchNorm2d: 3-224           128
# |    |    └─ReLU: 3-225                  --
# |    |    └─Conv2d: 3-226                36,864
# |    |    └─BatchNorm2d: 3-227           128
# |    └─BasicBlock: 2-46                  --
# |    |    └─Conv2d: 3-228                36,864
# |    |    └─BatchNorm2d: 3-229           128
# |    |    └─ReLU: 3-230                  --
# |    |    └─Conv2d: 3-231                36,864
# |    |    └─BatchNorm2d: 3-232           128
# |    └─BasicBlock: 2-47                  --
# |    |    └─Conv2d: 3-233                36,864
# |    |    └─BatchNorm2d: 3-234           128
# |    |    └─ReLU: 3-235                  --
# |    |    └─Conv2d: 3-236                36,864
# |    |    └─BatchNorm2d: 3-237           128
# |    └─BasicBlock: 2-48                  --
# |    |    └─Conv2d: 3-238                36,864
# |    |    └─BatchNorm2d: 3-239           128
# |    |    └─ReLU: 3-240                  --
# |    |    └─Conv2d: 3-241                36,864
# |    |    └─BatchNorm2d: 3-242           128
# |    └─BasicBlock: 2-49                  --
# |    |    └─Conv2d: 3-243                36,864
# |    |    └─BatchNorm2d: 3-244           128
# |    |    └─ReLU: 3-245                  --
# |    |    └─Conv2d: 3-246                36,864
# |    |    └─BatchNorm2d: 3-247           128
# |    └─BasicBlock: 2-50                  --
# |    |    └─Conv2d: 3-248                36,864
# |    |    └─BatchNorm2d: 3-249           128
# |    |    └─ReLU: 3-250                  --
# |    |    └─Conv2d: 3-251                36,864
# |    |    └─BatchNorm2d: 3-252           128
# |    └─BasicBlock: 2-51                  --
# |    |    └─Conv2d: 3-253                36,864
# |    |    └─BatchNorm2d: 3-254           128
# |    |    └─ReLU: 3-255                  --
# |    |    └─Conv2d: 3-256                36,864
# |    |    └─BatchNorm2d: 3-257           128
# |    └─BasicBlock: 2-52                  --
# |    |    └─Conv2d: 3-258                36,864
# |    |    └─BatchNorm2d: 3-259           128
# |    |    └─ReLU: 3-260                  --
# |    |    └─Conv2d: 3-261                36,864
# |    |    └─BatchNorm2d: 3-262           128
# |    └─BasicBlock: 2-53                  --
# |    |    └─Conv2d: 3-263                36,864
# |    |    └─BatchNorm2d: 3-264           128
# |    |    └─ReLU: 3-265                  --
# |    |    └─Conv2d: 3-266                36,864
# |    |    └─BatchNorm2d: 3-267           128
# |    └─BasicBlock: 2-54                  --
# |    |    └─Conv2d: 3-268                36,864
# |    |    └─BatchNorm2d: 3-269           128
# |    |    └─ReLU: 3-270                  --
# |    |    └─Conv2d: 3-271                36,864
# |    |    └─BatchNorm2d: 3-272           128
# ├─AvgPool2d: 1-7                         --
# ├─Linear: 1-8                            6,500
# =================================================================
# Total params: 1,736,564
# Trainable params: 1,736,564
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─BatchNorm2d: 1-2                       32
# ├─ReLU: 1-3                              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  2,304
# |    |    └─BatchNorm2d: 3-2             32
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  2,304
# |    |    └─BatchNorm2d: 3-5             32
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  2,304
# |    |    └─BatchNorm2d: 3-7             32
# |    |    └─ReLU: 3-8                    --
# |    |    └─Conv2d: 3-9                  2,304
# |    |    └─BatchNorm2d: 3-10            32
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 2,304
# |    |    └─BatchNorm2d: 3-12            32
# |    |    └─ReLU: 3-13                   --
# |    |    └─Conv2d: 3-14                 2,304
# |    |    └─BatchNorm2d: 3-15            32
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 2,304
# |    |    └─BatchNorm2d: 3-17            32
# |    |    └─ReLU: 3-18                   --
# |    |    └─Conv2d: 3-19                 2,304
# |    |    └─BatchNorm2d: 3-20            32
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 2,304
# |    |    └─BatchNorm2d: 3-22            32
# |    |    └─ReLU: 3-23                   --
# |    |    └─Conv2d: 3-24                 2,304
# |    |    └─BatchNorm2d: 3-25            32
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 4,608
# |    |    └─BatchNorm2d: 3-27            64
# |    |    └─ReLU: 3-28                   --
# |    |    └─Conv2d: 3-29                 9,216
# |    |    └─BatchNorm2d: 3-30            64
# |    |    └─Sequential: 3-31             576
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-32                 9,216
# |    |    └─BatchNorm2d: 3-33            64
# |    |    └─ReLU: 3-34                   --
# |    |    └─Conv2d: 3-35                 9,216
# |    |    └─BatchNorm2d: 3-36            64
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-37                 9,216
# |    |    └─BatchNorm2d: 3-38            64
# |    |    └─ReLU: 3-39                   --
# |    |    └─Conv2d: 3-40                 9,216
# |    |    └─BatchNorm2d: 3-41            64
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-42                 9,216
# |    |    └─BatchNorm2d: 3-43            64
# |    |    └─ReLU: 3-44                   --
# |    |    └─Conv2d: 3-45                 9,216
# |    |    └─BatchNorm2d: 3-46            64
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-47                 9,216
# |    |    └─BatchNorm2d: 3-48            64
# |    |    └─ReLU: 3-49                   --
# |    |    └─Conv2d: 3-50                 9,216
# |    |    └─BatchNorm2d: 3-51            64
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-52                 18,432
# |    |    └─BatchNorm2d: 3-53            128
# |    |    └─ReLU: 3-54                   --
# |    |    └─Conv2d: 3-55                 36,864
# |    |    └─BatchNorm2d: 3-56            128
# |    |    └─Sequential: 3-57             2,176
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-58                 36,864
# |    |    └─BatchNorm2d: 3-59            128
# |    |    └─ReLU: 3-60                   --
# |    |    └─Conv2d: 3-61                 36,864
# |    |    └─BatchNorm2d: 3-62            128
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-63                 36,864
# |    |    └─BatchNorm2d: 3-64            128
# |    |    └─ReLU: 3-65                   --
# |    |    └─Conv2d: 3-66                 36,864
# |    |    └─BatchNorm2d: 3-67            128
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-68                 36,864
# |    |    └─BatchNorm2d: 3-69            128
# |    |    └─ReLU: 3-70                   --
# |    |    └─Conv2d: 3-71                 36,864
# |    |    └─BatchNorm2d: 3-72            128
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-73                 36,864
# |    |    └─BatchNorm2d: 3-74            128
# |    |    └─ReLU: 3-75                   --
# |    |    └─Conv2d: 3-76                 36,864
# |    |    └─BatchNorm2d: 3-77            128
# ├─AvgPool2d: 1-7                         --
# ├─Linear: 1-8                            6,500
# =================================================================
# Total params: 472,756
# Trainable params: 472,756
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 23,808
# |    |    └─SepConv: 3-2                 43,216
# |    |    └─SepConv: 3-3                 56,304
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       6,500
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 23,808
# |    |    └─SepConv: 3-6                 43,216
# |    |    └─SepConv: 3-7                 56,304
# |    |    └─AvgPool2d: 3-8               --
# |    └─Linear: 2-4                       6,500
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-9                 43,216
# |    |    └─SepConv: 3-10                56,304
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-6                       6,500
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-12                56,304
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-8                       6,500
# ├─FinalClassifier: 1-5                   --
# |    └─Linear: 2-9                       6,500
# =================================================================
# Total params: 434,980
# Trainable params: 434,980
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              23,808
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              43,216
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              56,304
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 129,828
# Trainable params: 129,828
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              23,808
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              43,216
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              56,304
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 129,828
# Trainable params: 129,828
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              43,216
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              56,304
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 106,020
# Trainable params: 106,020
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              56,304
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 62,804
# Trainable params: 62,804
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            6,500
# =================================================================
# Total params: 6,500
# Trainable params: 6,500
# Non-trainable params: 0
# =================================================================

# %%
print("ResNet110 - ResNet32")
model_t_params = 1736564
model_s_params = 472756
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
model_s_ensemble1 = 432+32 + conv_distiller1
model_s_ensemble2 = 2304+32+2304+32+2304+32+2304+32+2304+32+2304+32+2304+32+2304+32+2304+32+2304+32 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 4608+64+9216+64+576+9216+64+9216+64+9216+64 +9216+64+9216+64+9216+64+9216+64+ conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 18432+128+36864+128+2176+36864+128+36864+128+36864+128+36864+128+36864+128 + conv_distiller4 + model_s_ensemble3
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# ResNet110 - ResNet32
# Teacher model: 1736564 (100.000%)
# Student model: 472756 (27.224%)
# Ensemble 1: 130292 (7.503%)
# Ensemble 2: 283480 (16.324%)
# Ensemble 3: 468988 (27.007%)
# Ensemble 4: 774480 (44.598%)
# Final Ensemble: 907736 (52.272%)

# %%
opt = {'model_t': 'resnet110',
       'model_s': 'resnet20',
       'path_t': './save/models/resnet110_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 230

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)



balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 16, 32, 32])
# 2 feature: torch.Size([1, 16, 32, 32])
# 3 feature: torch.Size([1, 32, 16, 16])
# 4 feature: torch.Size([1, 64, 8, 8])
# 5 feature: torch.Size([1, 64])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─BatchNorm2d: 1-2                       32
# ├─ReLU: 1-3                              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  2,304
# |    |    └─BatchNorm2d: 3-2             32
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  2,304
# |    |    └─BatchNorm2d: 3-5             32
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  2,304
# |    |    └─BatchNorm2d: 3-7             32
# |    |    └─ReLU: 3-8                    --
# |    |    └─Conv2d: 3-9                  2,304
# |    |    └─BatchNorm2d: 3-10            32
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 2,304
# |    |    └─BatchNorm2d: 3-12            32
# |    |    └─ReLU: 3-13                   --
# |    |    └─Conv2d: 3-14                 2,304
# |    |    └─BatchNorm2d: 3-15            32
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 2,304
# |    |    └─BatchNorm2d: 3-17            32
# |    |    └─ReLU: 3-18                   --
# |    |    └─Conv2d: 3-19                 2,304
# |    |    └─BatchNorm2d: 3-20            32
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 2,304
# |    |    └─BatchNorm2d: 3-22            32
# |    |    └─ReLU: 3-23                   --
# |    |    └─Conv2d: 3-24                 2,304
# |    |    └─BatchNorm2d: 3-25            32
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 2,304
# |    |    └─BatchNorm2d: 3-27            32
# |    |    └─ReLU: 3-28                   --
# |    |    └─Conv2d: 3-29                 2,304
# |    |    └─BatchNorm2d: 3-30            32
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 2,304
# |    |    └─BatchNorm2d: 3-32            32
# |    |    └─ReLU: 3-33                   --
# |    |    └─Conv2d: 3-34                 2,304
# |    |    └─BatchNorm2d: 3-35            32
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 2,304
# |    |    └─BatchNorm2d: 3-37            32
# |    |    └─ReLU: 3-38                   --
# |    |    └─Conv2d: 3-39                 2,304
# |    |    └─BatchNorm2d: 3-40            32
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 2,304
# |    |    └─BatchNorm2d: 3-42            32
# |    |    └─ReLU: 3-43                   --
# |    |    └─Conv2d: 3-44                 2,304
# |    |    └─BatchNorm2d: 3-45            32
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-46                 2,304
# |    |    └─BatchNorm2d: 3-47            32
# |    |    └─ReLU: 3-48                   --
# |    |    └─Conv2d: 3-49                 2,304
# |    |    └─BatchNorm2d: 3-50            32
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-51                 2,304
# |    |    └─BatchNorm2d: 3-52            32
# |    |    └─ReLU: 3-53                   --
# |    |    └─Conv2d: 3-54                 2,304
# |    |    └─BatchNorm2d: 3-55            32
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-56                 2,304
# |    |    └─BatchNorm2d: 3-57            32
# |    |    └─ReLU: 3-58                   --
# |    |    └─Conv2d: 3-59                 2,304
# |    |    └─BatchNorm2d: 3-60            32
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-61                 2,304
# |    |    └─BatchNorm2d: 3-62            32
# |    |    └─ReLU: 3-63                   --
# |    |    └─Conv2d: 3-64                 2,304
# |    |    └─BatchNorm2d: 3-65            32
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-66                 2,304
# |    |    └─BatchNorm2d: 3-67            32
# |    |    └─ReLU: 3-68                   --
# |    |    └─Conv2d: 3-69                 2,304
# |    |    └─BatchNorm2d: 3-70            32
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-71                 2,304
# |    |    └─BatchNorm2d: 3-72            32
# |    |    └─ReLU: 3-73                   --
# |    |    └─Conv2d: 3-74                 2,304
# |    |    └─BatchNorm2d: 3-75            32
# |    └─BasicBlock: 2-16                  --
# |    |    └─Conv2d: 3-76                 2,304
# |    |    └─BatchNorm2d: 3-77            32
# |    |    └─ReLU: 3-78                   --
# |    |    └─Conv2d: 3-79                 2,304
# |    |    └─BatchNorm2d: 3-80            32
# |    └─BasicBlock: 2-17                  --
# |    |    └─Conv2d: 3-81                 2,304
# |    |    └─BatchNorm2d: 3-82            32
# |    |    └─ReLU: 3-83                   --
# |    |    └─Conv2d: 3-84                 2,304
# |    |    └─BatchNorm2d: 3-85            32
# |    └─BasicBlock: 2-18                  --
# |    |    └─Conv2d: 3-86                 2,304
# |    |    └─BatchNorm2d: 3-87            32
# |    |    └─ReLU: 3-88                   --
# |    |    └─Conv2d: 3-89                 2,304
# |    |    └─BatchNorm2d: 3-90            32
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-19                  --
# |    |    └─Conv2d: 3-91                 4,608
# |    |    └─BatchNorm2d: 3-92            64
# |    |    └─ReLU: 3-93                   --
# |    |    └─Conv2d: 3-94                 9,216
# |    |    └─BatchNorm2d: 3-95            64
# |    |    └─Sequential: 3-96             576
# |    └─BasicBlock: 2-20                  --
# |    |    └─Conv2d: 3-97                 9,216
# |    |    └─BatchNorm2d: 3-98            64
# |    |    └─ReLU: 3-99                   --
# |    |    └─Conv2d: 3-100                9,216
# |    |    └─BatchNorm2d: 3-101           64
# |    └─BasicBlock: 2-21                  --
# |    |    └─Conv2d: 3-102                9,216
# |    |    └─BatchNorm2d: 3-103           64
# |    |    └─ReLU: 3-104                  --
# |    |    └─Conv2d: 3-105                9,216
# |    |    └─BatchNorm2d: 3-106           64
# |    └─BasicBlock: 2-22                  --
# |    |    └─Conv2d: 3-107                9,216
# |    |    └─BatchNorm2d: 3-108           64
# |    |    └─ReLU: 3-109                  --
# |    |    └─Conv2d: 3-110                9,216
# |    |    └─BatchNorm2d: 3-111           64
# |    └─BasicBlock: 2-23                  --
# |    |    └─Conv2d: 3-112                9,216
# |    |    └─BatchNorm2d: 3-113           64
# |    |    └─ReLU: 3-114                  --
# |    |    └─Conv2d: 3-115                9,216
# |    |    └─BatchNorm2d: 3-116           64
# |    └─BasicBlock: 2-24                  --
# |    |    └─Conv2d: 3-117                9,216
# |    |    └─BatchNorm2d: 3-118           64
# |    |    └─ReLU: 3-119                  --
# |    |    └─Conv2d: 3-120                9,216
# |    |    └─BatchNorm2d: 3-121           64
# |    └─BasicBlock: 2-25                  --
# |    |    └─Conv2d: 3-122                9,216
# |    |    └─BatchNorm2d: 3-123           64
# |    |    └─ReLU: 3-124                  --
# |    |    └─Conv2d: 3-125                9,216
# |    |    └─BatchNorm2d: 3-126           64
# |    └─BasicBlock: 2-26                  --
# |    |    └─Conv2d: 3-127                9,216
# |    |    └─BatchNorm2d: 3-128           64
# |    |    └─ReLU: 3-129                  --
# |    |    └─Conv2d: 3-130                9,216
# |    |    └─BatchNorm2d: 3-131           64
# |    └─BasicBlock: 2-27                  --
# |    |    └─Conv2d: 3-132                9,216
# |    |    └─BatchNorm2d: 3-133           64
# |    |    └─ReLU: 3-134                  --
# |    |    └─Conv2d: 3-135                9,216
# |    |    └─BatchNorm2d: 3-136           64
# |    └─BasicBlock: 2-28                  --
# |    |    └─Conv2d: 3-137                9,216
# |    |    └─BatchNorm2d: 3-138           64
# |    |    └─ReLU: 3-139                  --
# |    |    └─Conv2d: 3-140                9,216
# |    |    └─BatchNorm2d: 3-141           64
# |    └─BasicBlock: 2-29                  --
# |    |    └─Conv2d: 3-142                9,216
# |    |    └─BatchNorm2d: 3-143           64
# |    |    └─ReLU: 3-144                  --
# |    |    └─Conv2d: 3-145                9,216
# |    |    └─BatchNorm2d: 3-146           64
# |    └─BasicBlock: 2-30                  --
# |    |    └─Conv2d: 3-147                9,216
# |    |    └─BatchNorm2d: 3-148           64
# |    |    └─ReLU: 3-149                  --
# |    |    └─Conv2d: 3-150                9,216
# |    |    └─BatchNorm2d: 3-151           64
# |    └─BasicBlock: 2-31                  --
# |    |    └─Conv2d: 3-152                9,216
# |    |    └─BatchNorm2d: 3-153           64
# |    |    └─ReLU: 3-154                  --
# |    |    └─Conv2d: 3-155                9,216
# |    |    └─BatchNorm2d: 3-156           64
# |    └─BasicBlock: 2-32                  --
# |    |    └─Conv2d: 3-157                9,216
# |    |    └─BatchNorm2d: 3-158           64
# |    |    └─ReLU: 3-159                  --
# |    |    └─Conv2d: 3-160                9,216
# |    |    └─BatchNorm2d: 3-161           64
# |    └─BasicBlock: 2-33                  --
# |    |    └─Conv2d: 3-162                9,216
# |    |    └─BatchNorm2d: 3-163           64
# |    |    └─ReLU: 3-164                  --
# |    |    └─Conv2d: 3-165                9,216
# |    |    └─BatchNorm2d: 3-166           64
# |    └─BasicBlock: 2-34                  --
# |    |    └─Conv2d: 3-167                9,216
# |    |    └─BatchNorm2d: 3-168           64
# |    |    └─ReLU: 3-169                  --
# |    |    └─Conv2d: 3-170                9,216
# |    |    └─BatchNorm2d: 3-171           64
# |    └─BasicBlock: 2-35                  --
# |    |    └─Conv2d: 3-172                9,216
# |    |    └─BatchNorm2d: 3-173           64
# |    |    └─ReLU: 3-174                  --
# |    |    └─Conv2d: 3-175                9,216
# |    |    └─BatchNorm2d: 3-176           64
# |    └─BasicBlock: 2-36                  --
# |    |    └─Conv2d: 3-177                9,216
# |    |    └─BatchNorm2d: 3-178           64
# |    |    └─ReLU: 3-179                  --
# |    |    └─Conv2d: 3-180                9,216
# |    |    └─BatchNorm2d: 3-181           64
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-37                  --
# |    |    └─Conv2d: 3-182                18,432
# |    |    └─BatchNorm2d: 3-183           128
# |    |    └─ReLU: 3-184                  --
# |    |    └─Conv2d: 3-185                36,864
# |    |    └─BatchNorm2d: 3-186           128
# |    |    └─Sequential: 3-187            2,176
# |    └─BasicBlock: 2-38                  --
# |    |    └─Conv2d: 3-188                36,864
# |    |    └─BatchNorm2d: 3-189           128
# |    |    └─ReLU: 3-190                  --
# |    |    └─Conv2d: 3-191                36,864
# |    |    └─BatchNorm2d: 3-192           128
# |    └─BasicBlock: 2-39                  --
# |    |    └─Conv2d: 3-193                36,864
# |    |    └─BatchNorm2d: 3-194           128
# |    |    └─ReLU: 3-195                  --
# |    |    └─Conv2d: 3-196                36,864
# |    |    └─BatchNorm2d: 3-197           128
# |    └─BasicBlock: 2-40                  --
# |    |    └─Conv2d: 3-198                36,864
# |    |    └─BatchNorm2d: 3-199           128
# |    |    └─ReLU: 3-200                  --
# |    |    └─Conv2d: 3-201                36,864
# |    |    └─BatchNorm2d: 3-202           128
# |    └─BasicBlock: 2-41                  --
# |    |    └─Conv2d: 3-203                36,864
# |    |    └─BatchNorm2d: 3-204           128
# |    |    └─ReLU: 3-205                  --
# |    |    └─Conv2d: 3-206                36,864
# |    |    └─BatchNorm2d: 3-207           128
# |    └─BasicBlock: 2-42                  --
# |    |    └─Conv2d: 3-208                36,864
# |    |    └─BatchNorm2d: 3-209           128
# |    |    └─ReLU: 3-210                  --
# |    |    └─Conv2d: 3-211                36,864
# |    |    └─BatchNorm2d: 3-212           128
# |    └─BasicBlock: 2-43                  --
# |    |    └─Conv2d: 3-213                36,864
# |    |    └─BatchNorm2d: 3-214           128
# |    |    └─ReLU: 3-215                  --
# |    |    └─Conv2d: 3-216                36,864
# |    |    └─BatchNorm2d: 3-217           128
# |    └─BasicBlock: 2-44                  --
# |    |    └─Conv2d: 3-218                36,864
# |    |    └─BatchNorm2d: 3-219           128
# |    |    └─ReLU: 3-220                  --
# |    |    └─Conv2d: 3-221                36,864
# |    |    └─BatchNorm2d: 3-222           128
# |    └─BasicBlock: 2-45                  --
# |    |    └─Conv2d: 3-223                36,864
# |    |    └─BatchNorm2d: 3-224           128
# |    |    └─ReLU: 3-225                  --
# |    |    └─Conv2d: 3-226                36,864
# |    |    └─BatchNorm2d: 3-227           128
# |    └─BasicBlock: 2-46                  --
# |    |    └─Conv2d: 3-228                36,864
# |    |    └─BatchNorm2d: 3-229           128
# |    |    └─ReLU: 3-230                  --
# |    |    └─Conv2d: 3-231                36,864
# |    |    └─BatchNorm2d: 3-232           128
# |    └─BasicBlock: 2-47                  --
# |    |    └─Conv2d: 3-233                36,864
# |    |    └─BatchNorm2d: 3-234           128
# |    |    └─ReLU: 3-235                  --
# |    |    └─Conv2d: 3-236                36,864
# |    |    └─BatchNorm2d: 3-237           128
# |    └─BasicBlock: 2-48                  --
# |    |    └─Conv2d: 3-238                36,864
# |    |    └─BatchNorm2d: 3-239           128
# |    |    └─ReLU: 3-240                  --
# |    |    └─Conv2d: 3-241                36,864
# |    |    └─BatchNorm2d: 3-242           128
# |    └─BasicBlock: 2-49                  --
# |    |    └─Conv2d: 3-243                36,864
# |    |    └─BatchNorm2d: 3-244           128
# |    |    └─ReLU: 3-245                  --
# |    |    └─Conv2d: 3-246                36,864
# |    |    └─BatchNorm2d: 3-247           128
# |    └─BasicBlock: 2-50                  --
# |    |    └─Conv2d: 3-248                36,864
# |    |    └─BatchNorm2d: 3-249           128
# |    |    └─ReLU: 3-250                  --
# |    |    └─Conv2d: 3-251                36,864
# |    |    └─BatchNorm2d: 3-252           128
# |    └─BasicBlock: 2-51                  --
# |    |    └─Conv2d: 3-253                36,864
# |    |    └─BatchNorm2d: 3-254           128
# |    |    └─ReLU: 3-255                  --
# |    |    └─Conv2d: 3-256                36,864
# |    |    └─BatchNorm2d: 3-257           128
# |    └─BasicBlock: 2-52                  --
# |    |    └─Conv2d: 3-258                36,864
# |    |    └─BatchNorm2d: 3-259           128
# |    |    └─ReLU: 3-260                  --
# |    |    └─Conv2d: 3-261                36,864
# |    |    └─BatchNorm2d: 3-262           128
# |    └─BasicBlock: 2-53                  --
# |    |    └─Conv2d: 3-263                36,864
# |    |    └─BatchNorm2d: 3-264           128
# |    |    └─ReLU: 3-265                  --
# |    |    └─Conv2d: 3-266                36,864
# |    |    └─BatchNorm2d: 3-267           128
# |    └─BasicBlock: 2-54                  --
# |    |    └─Conv2d: 3-268                36,864
# |    |    └─BatchNorm2d: 3-269           128
# |    |    └─ReLU: 3-270                  --
# |    |    └─Conv2d: 3-271                36,864
# |    |    └─BatchNorm2d: 3-272           128
# ├─AvgPool2d: 1-7                         --
# ├─Linear: 1-8                            6,500
# =================================================================
# Total params: 1,736,564
# Trainable params: 1,736,564
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─BatchNorm2d: 1-2                       32
# ├─ReLU: 1-3                              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  2,304
# |    |    └─BatchNorm2d: 3-2             32
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  2,304
# |    |    └─BatchNorm2d: 3-5             32
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  2,304
# |    |    └─BatchNorm2d: 3-7             32
# |    |    └─ReLU: 3-8                    --
# |    |    └─Conv2d: 3-9                  2,304
# |    |    └─BatchNorm2d: 3-10            32
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 2,304
# |    |    └─BatchNorm2d: 3-12            32
# |    |    └─ReLU: 3-13                   --
# |    |    └─Conv2d: 3-14                 2,304
# |    |    └─BatchNorm2d: 3-15            32
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 4,608
# |    |    └─BatchNorm2d: 3-17            64
# |    |    └─ReLU: 3-18                   --
# |    |    └─Conv2d: 3-19                 9,216
# |    |    └─BatchNorm2d: 3-20            64
# |    |    └─Sequential: 3-21             576
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-22                 9,216
# |    |    └─BatchNorm2d: 3-23            64
# |    |    └─ReLU: 3-24                   --
# |    |    └─Conv2d: 3-25                 9,216
# |    |    └─BatchNorm2d: 3-26            64
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-27                 9,216
# |    |    └─BatchNorm2d: 3-28            64
# |    |    └─ReLU: 3-29                   --
# |    |    └─Conv2d: 3-30                 9,216
# |    |    └─BatchNorm2d: 3-31            64
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-32                 18,432
# |    |    └─BatchNorm2d: 3-33            128
# |    |    └─ReLU: 3-34                   --
# |    |    └─Conv2d: 3-35                 36,864
# |    |    └─BatchNorm2d: 3-36            128
# |    |    └─Sequential: 3-37             2,176
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-38                 36,864
# |    |    └─BatchNorm2d: 3-39            128
# |    |    └─ReLU: 3-40                   --
# |    |    └─Conv2d: 3-41                 36,864
# |    |    └─BatchNorm2d: 3-42            128
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-43                 36,864
# |    |    └─BatchNorm2d: 3-44            128
# |    |    └─ReLU: 3-45                   --
# |    |    └─Conv2d: 3-46                 36,864
# |    |    └─BatchNorm2d: 3-47            128
# ├─AvgPool2d: 1-7                         --
# ├─Linear: 1-8                            6,500
# =================================================================
# Total params: 278,324
# Trainable params: 278,324
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 13,778
# |    |    └─SepConv: 3-2                 25,026
# |    |    └─SepConv: 3-3                 32,674
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       6,500
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 13,778
# |    |    └─SepConv: 3-6                 25,026
# |    |    └─SepConv: 3-7                 32,674
# |    |    └─AvgPool2d: 3-8               --
# |    └─Linear: 2-4                       6,500
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-9                 25,026
# |    |    └─SepConv: 3-10                32,674
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-6                       6,500
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-12                32,674
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-8                       6,500
# ├─FinalClassifier: 1-5                   --
# |    └─Linear: 2-9                       6,500
# =================================================================
# Total params: 265,830
# Trainable params: 265,830
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              13,778
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              25,026
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              32,674
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 77,978
# Trainable params: 77,978
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              13,778
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              25,026
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              32,674
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 77,978
# Trainable params: 77,978
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              25,026
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              32,674
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 64,200
# Trainable params: 64,200
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              32,674
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 39,174
# Trainable params: 39,174
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            6,500
# =================================================================
# Total params: 6,500
# Trainable params: 6,500
# Non-trainable params: 0
# =================================================================

# %%
print("ResNet110 - ResNet20")
model_t_params = 1736564
model_s_params = 278324
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
model_s_ensemble1 = 432+32 + conv_distiller1
model_s_ensemble2 = 2304+32+2304+32+2304+32+2304+32+2304+32+2304+32 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 4608+64+9216+64+576+9216+64+9216+64+9216+64 + conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 18432+128+36864+128+2176+36864+128+36864+128+36864+128 + conv_distiller4 + model_s_ensemble3
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# ResNet110 - ResNet20
# Teacher model: 1736564 (100.000%)
# Student model: 278324 (16.027%)
# Ensemble 1: 78442 (4.517%)
# Ensemble 2: 170436 (9.815%)
# Ensemble 3: 277004 (15.951%)
# Ensemble 4: 484882 (27.922%)
# Final Ensemble: 544154 (31.335%)

# %%
opt = {'model_t': 'resnet56',
       'model_s': 'resnet20',
       'path_t': './save/models/resnet56_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 230

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)


balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 16, 32, 32])
# 2 feature: torch.Size([1, 16, 32, 32])
# 3 feature: torch.Size([1, 32, 16, 16])
# 4 feature: torch.Size([1, 64, 8, 8])
# 5 feature: torch.Size([1, 64])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─BatchNorm2d: 1-2                       32
# ├─ReLU: 1-3                              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  2,304
# |    |    └─BatchNorm2d: 3-2             32
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  2,304
# |    |    └─BatchNorm2d: 3-5             32
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  2,304
# |    |    └─BatchNorm2d: 3-7             32
# |    |    └─ReLU: 3-8                    --
# |    |    └─Conv2d: 3-9                  2,304
# |    |    └─BatchNorm2d: 3-10            32
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 2,304
# |    |    └─BatchNorm2d: 3-12            32
# |    |    └─ReLU: 3-13                   --
# |    |    └─Conv2d: 3-14                 2,304
# |    |    └─BatchNorm2d: 3-15            32
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 2,304
# |    |    └─BatchNorm2d: 3-17            32
# |    |    └─ReLU: 3-18                   --
# |    |    └─Conv2d: 3-19                 2,304
# |    |    └─BatchNorm2d: 3-20            32
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 2,304
# |    |    └─BatchNorm2d: 3-22            32
# |    |    └─ReLU: 3-23                   --
# |    |    └─Conv2d: 3-24                 2,304
# |    |    └─BatchNorm2d: 3-25            32
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 2,304
# |    |    └─BatchNorm2d: 3-27            32
# |    |    └─ReLU: 3-28                   --
# |    |    └─Conv2d: 3-29                 2,304
# |    |    └─BatchNorm2d: 3-30            32
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 2,304
# |    |    └─BatchNorm2d: 3-32            32
# |    |    └─ReLU: 3-33                   --
# |    |    └─Conv2d: 3-34                 2,304
# |    |    └─BatchNorm2d: 3-35            32
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 2,304
# |    |    └─BatchNorm2d: 3-37            32
# |    |    └─ReLU: 3-38                   --
# |    |    └─Conv2d: 3-39                 2,304
# |    |    └─BatchNorm2d: 3-40            32
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 2,304
# |    |    └─BatchNorm2d: 3-42            32
# |    |    └─ReLU: 3-43                   --
# |    |    └─Conv2d: 3-44                 2,304
# |    |    └─BatchNorm2d: 3-45            32
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-46                 4,608
# |    |    └─BatchNorm2d: 3-47            64
# |    |    └─ReLU: 3-48                   --
# |    |    └─Conv2d: 3-49                 9,216
# |    |    └─BatchNorm2d: 3-50            64
# |    |    └─Sequential: 3-51             576
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-52                 9,216
# |    |    └─BatchNorm2d: 3-53            64
# |    |    └─ReLU: 3-54                   --
# |    |    └─Conv2d: 3-55                 9,216
# |    |    └─BatchNorm2d: 3-56            64
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-57                 9,216
# |    |    └─BatchNorm2d: 3-58            64
# |    |    └─ReLU: 3-59                   --
# |    |    └─Conv2d: 3-60                 9,216
# |    |    └─BatchNorm2d: 3-61            64
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-62                 9,216
# |    |    └─BatchNorm2d: 3-63            64
# |    |    └─ReLU: 3-64                   --
# |    |    └─Conv2d: 3-65                 9,216
# |    |    └─BatchNorm2d: 3-66            64
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-67                 9,216
# |    |    └─BatchNorm2d: 3-68            64
# |    |    └─ReLU: 3-69                   --
# |    |    └─Conv2d: 3-70                 9,216
# |    |    └─BatchNorm2d: 3-71            64
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-72                 9,216
# |    |    └─BatchNorm2d: 3-73            64
# |    |    └─ReLU: 3-74                   --
# |    |    └─Conv2d: 3-75                 9,216
# |    |    └─BatchNorm2d: 3-76            64
# |    └─BasicBlock: 2-16                  --
# |    |    └─Conv2d: 3-77                 9,216
# |    |    └─BatchNorm2d: 3-78            64
# |    |    └─ReLU: 3-79                   --
# |    |    └─Conv2d: 3-80                 9,216
# |    |    └─BatchNorm2d: 3-81            64
# |    └─BasicBlock: 2-17                  --
# |    |    └─Conv2d: 3-82                 9,216
# |    |    └─BatchNorm2d: 3-83            64
# |    |    └─ReLU: 3-84                   --
# |    |    └─Conv2d: 3-85                 9,216
# |    |    └─BatchNorm2d: 3-86            64
# |    └─BasicBlock: 2-18                  --
# |    |    └─Conv2d: 3-87                 9,216
# |    |    └─BatchNorm2d: 3-88            64
# |    |    └─ReLU: 3-89                   --
# |    |    └─Conv2d: 3-90                 9,216
# |    |    └─BatchNorm2d: 3-91            64
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-19                  --
# |    |    └─Conv2d: 3-92                 18,432
# |    |    └─BatchNorm2d: 3-93            128
# |    |    └─ReLU: 3-94                   --
# |    |    └─Conv2d: 3-95                 36,864
# |    |    └─BatchNorm2d: 3-96            128
# |    |    └─Sequential: 3-97             2,176
# |    └─BasicBlock: 2-20                  --
# |    |    └─Conv2d: 3-98                 36,864
# |    |    └─BatchNorm2d: 3-99            128
# |    |    └─ReLU: 3-100                  --
# |    |    └─Conv2d: 3-101                36,864
# |    |    └─BatchNorm2d: 3-102           128
# |    └─BasicBlock: 2-21                  --
# |    |    └─Conv2d: 3-103                36,864
# |    |    └─BatchNorm2d: 3-104           128
# |    |    └─ReLU: 3-105                  --
# |    |    └─Conv2d: 3-106                36,864
# |    |    └─BatchNorm2d: 3-107           128
# |    └─BasicBlock: 2-22                  --
# |    |    └─Conv2d: 3-108                36,864
# |    |    └─BatchNorm2d: 3-109           128
# |    |    └─ReLU: 3-110                  --
# |    |    └─Conv2d: 3-111                36,864
# |    |    └─BatchNorm2d: 3-112           128
# |    └─BasicBlock: 2-23                  --
# |    |    └─Conv2d: 3-113                36,864
# |    |    └─BatchNorm2d: 3-114           128
# |    |    └─ReLU: 3-115                  --
# |    |    └─Conv2d: 3-116                36,864
# |    |    └─BatchNorm2d: 3-117           128
# |    └─BasicBlock: 2-24                  --
# |    |    └─Conv2d: 3-118                36,864
# |    |    └─BatchNorm2d: 3-119           128
# |    |    └─ReLU: 3-120                  --
# |    |    └─Conv2d: 3-121                36,864
# |    |    └─BatchNorm2d: 3-122           128
# |    └─BasicBlock: 2-25                  --
# |    |    └─Conv2d: 3-123                36,864
# |    |    └─BatchNorm2d: 3-124           128
# |    |    └─ReLU: 3-125                  --
# |    |    └─Conv2d: 3-126                36,864
# |    |    └─BatchNorm2d: 3-127           128
# |    └─BasicBlock: 2-26                  --
# |    |    └─Conv2d: 3-128                36,864
# |    |    └─BatchNorm2d: 3-129           128
# |    |    └─ReLU: 3-130                  --
# |    |    └─Conv2d: 3-131                36,864
# |    |    └─BatchNorm2d: 3-132           128
# |    └─BasicBlock: 2-27                  --
# |    |    └─Conv2d: 3-133                36,864
# |    |    └─BatchNorm2d: 3-134           128
# |    |    └─ReLU: 3-135                  --
# |    |    └─Conv2d: 3-136                36,864
# |    |    └─BatchNorm2d: 3-137           128
# ├─AvgPool2d: 1-7                         --
# ├─Linear: 1-8                            6,500
# =================================================================
# Total params: 861,620
# Trainable params: 861,620
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─BatchNorm2d: 1-2                       32
# ├─ReLU: 1-3                              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  2,304
# |    |    └─BatchNorm2d: 3-2             32
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  2,304
# |    |    └─BatchNorm2d: 3-5             32
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  2,304
# |    |    └─BatchNorm2d: 3-7             32
# |    |    └─ReLU: 3-8                    --
# |    |    └─Conv2d: 3-9                  2,304
# |    |    └─BatchNorm2d: 3-10            32
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 2,304
# |    |    └─BatchNorm2d: 3-12            32
# |    |    └─ReLU: 3-13                   --
# |    |    └─Conv2d: 3-14                 2,304
# |    |    └─BatchNorm2d: 3-15            32
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 4,608
# |    |    └─BatchNorm2d: 3-17            64
# |    |    └─ReLU: 3-18                   --
# |    |    └─Conv2d: 3-19                 9,216
# |    |    └─BatchNorm2d: 3-20            64
# |    |    └─Sequential: 3-21             576
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-22                 9,216
# |    |    └─BatchNorm2d: 3-23            64
# |    |    └─ReLU: 3-24                   --
# |    |    └─Conv2d: 3-25                 9,216
# |    |    └─BatchNorm2d: 3-26            64
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-27                 9,216
# |    |    └─BatchNorm2d: 3-28            64
# |    |    └─ReLU: 3-29                   --
# |    |    └─Conv2d: 3-30                 9,216
# |    |    └─BatchNorm2d: 3-31            64
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-32                 18,432
# |    |    └─BatchNorm2d: 3-33            128
# |    |    └─ReLU: 3-34                   --
# |    |    └─Conv2d: 3-35                 36,864
# |    |    └─BatchNorm2d: 3-36            128
# |    |    └─Sequential: 3-37             2,176
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-38                 36,864
# |    |    └─BatchNorm2d: 3-39            128
# |    |    └─ReLU: 3-40                   --
# |    |    └─Conv2d: 3-41                 36,864
# |    |    └─BatchNorm2d: 3-42            128
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-43                 36,864
# |    |    └─BatchNorm2d: 3-44            128
# |    |    └─ReLU: 3-45                   --
# |    |    └─Conv2d: 3-46                 36,864
# |    |    └─BatchNorm2d: 3-47            128
# ├─AvgPool2d: 1-7                         --
# ├─Linear: 1-8                            6,500
# =================================================================
# Total params: 278,324
# Trainable params: 278,324
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 13,778
# |    |    └─SepConv: 3-2                 25,026
# |    |    └─SepConv: 3-3                 32,674
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       6,500
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 13,778
# |    |    └─SepConv: 3-6                 25,026
# |    |    └─SepConv: 3-7                 32,674
# |    |    └─AvgPool2d: 3-8               --
# |    └─Linear: 2-4                       6,500
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-9                 25,026
# |    |    └─SepConv: 3-10                32,674
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-6                       6,500
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-12                32,674
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-8                       6,500
# ├─FinalClassifier: 1-5                   --
# |    └─Linear: 2-9                       6,500
# =================================================================
# Total params: 265,830
# Trainable params: 265,830
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              13,778
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              25,026
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              32,674
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 77,978
# Trainable params: 77,978
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              13,778
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              25,026
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              32,674
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 77,978
# Trainable params: 77,978
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              25,026
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              32,674
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 64,200
# Trainable params: 64,200
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              32,674
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            6,500
# =================================================================
# Total params: 39,174
# Trainable params: 39,174
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            6,500
# =================================================================
# Total params: 6,500
# Trainable params: 6,500
# Non-trainable params: 0
# =================================================================

# %%
print("ResNet56 - ResNet20")
model_t_params = 861620
model_s_params = 278324
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
model_s_ensemble1 = 432+32 + conv_distiller1
model_s_ensemble2 = 2304+32+2304+32+2304+32+2304+32+2304+32+2304+32 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 4608+64+9216+64+576+9216+64+9216+64+9216+64 + conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 18432+128+36864+128+2176+36864+128+36864+128+36864+128 + conv_distiller4 + model_s_ensemble3
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# ResNet56 - ResNet20
# Teacher model: 861620 (100.000%)
# Student model: 278324 (32.302%)
# Ensemble 1: 78442 (9.104%)
# Ensemble 2: 170436 (19.781%)
# Ensemble 3: 277004 (32.149%)
# Ensemble 4: 484882 (56.276%)
# Final Ensemble: 544154 (63.155%)

# %%
opt = {'model_t': 'wrn_40_2',
       'model_s': 'wrn_16_2',
       'path_t': './save/models/wrn_40_2_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 344

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)


balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 16, 32, 32])
# 2 feature: torch.Size([1, 32, 32, 32])
# 3 feature: torch.Size([1, 64, 16, 16])
# 4 feature: torch.Size([1, 128, 8, 8])
# 5 feature: torch.Size([1, 128])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─NetworkBlock: 1-2                      --
# |    └─Sequential: 2-1                   --
# |    |    └─BasicBlock: 3-1              14,432
# |    |    └─BasicBlock: 3-2              18,560
# |    |    └─BasicBlock: 3-3              18,560
# |    |    └─BasicBlock: 3-4              18,560
# |    |    └─BasicBlock: 3-5              18,560
# |    |    └─BasicBlock: 3-6              18,560
# ├─NetworkBlock: 1-3                      --
# |    └─Sequential: 2-2                   --
# |    |    └─BasicBlock: 3-7              57,536
# |    |    └─BasicBlock: 3-8              73,984
# |    |    └─BasicBlock: 3-9              73,984
# |    |    └─BasicBlock: 3-10             73,984
# |    |    └─BasicBlock: 3-11             73,984
# |    |    └─BasicBlock: 3-12             73,984
# ├─NetworkBlock: 1-4                      --
# |    └─Sequential: 2-3                   --
# |    |    └─BasicBlock: 3-13             229,760
# |    |    └─BasicBlock: 3-14             295,424
# |    |    └─BasicBlock: 3-15             295,424
# |    |    └─BasicBlock: 3-16             295,424
# |    |    └─BasicBlock: 3-17             295,424
# |    |    └─BasicBlock: 3-18             295,424
# ├─BatchNorm2d: 1-5                       256
# ├─ReLU: 1-6                              --
# ├─Linear: 1-7                            12,900
# =================================================================
# Total params: 2,255,156
# Trainable params: 2,255,156
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─NetworkBlock: 1-2                      --
# |    └─Sequential: 2-1                   --
# |    |    └─BasicBlock: 3-1              14,432
# |    |    └─BasicBlock: 3-2              18,560
# ├─NetworkBlock: 1-3                      --
# |    └─Sequential: 2-2                   --
# |    |    └─BasicBlock: 3-3              57,536
# |    |    └─BasicBlock: 3-4              73,984
# ├─NetworkBlock: 1-4                      --
# |    └─Sequential: 2-3                   --
# |    |    └─BasicBlock: 3-5              229,760
# |    |    └─BasicBlock: 3-6              295,424
# ├─BatchNorm2d: 1-5                       256
# ├─ReLU: 1-6                              --
# ├─Linear: 1-7                            12,900
# =================================================================
# Total params: 703,284
# Trainable params: 703,284
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 20,504
# |    |    └─SepConv: 3-2                 37,224
# |    |    └─SepConv: 3-3                 70,664
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       12,900
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 37,224
# |    |    └─SepConv: 3-6                 70,664
# |    |    └─SepConv: 3-7                 93,256
# |    |    └─AvgPool2d: 3-8               --
# |    └─Linear: 2-4                       12,900
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-9                 70,664
# |    |    └─SepConv: 3-10                93,256
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-6                       12,900
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-12                93,256
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-8                       12,900
# ├─FinalClassifier: 1-5                   --
# |    └─Linear: 2-9                       12,900
# =================================================================
# Total params: 651,212
# Trainable params: 651,212
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              20,504
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              37,224
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              70,664
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            12,900
# =================================================================
# Total params: 141,292
# Trainable params: 141,292
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              37,224
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              70,664
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              93,256
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            12,900
# =================================================================
# Total params: 214,044
# Trainable params: 214,044
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              70,664
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              93,256
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            12,900
# =================================================================
# Total params: 176,820
# Trainable params: 176,820
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              93,256
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            12,900
# =================================================================
# Total params: 106,156
# Trainable params: 106,156
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            12,900
# =================================================================
# Total params: 12,900
# Trainable params: 12,900
# Non-trainable params: 0
# =================================================================

# %%
print("WRN40-2 - WRN16-2")
model_t_params = 2255156
model_s_params = 703284
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
model_s_ensemble1 = 432 + conv_distiller1
model_s_ensemble2 = 14432+18560 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 57536+73984 + conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 229760+295424+256 + conv_distiller4 + model_s_ensemble3
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# WRN40-2 - WRN16-2
# Teacher model: 2255156 (100.000%)
# Student model: 703284 (31.186%)
# Ensemble 1: 141724 (6.284%)
# Ensemble 2: 388760 (17.239%)
# Ensemble 3: 697100 (30.911%)
# Ensemble 4: 1328696 (58.918%)
# Final Ensemble: 1354496 (60.062%)

# %%
opt = {'model_t': 'wrn_40_4',
       'model_s': 'wrn_16_4',
       'path_t': './save/models/wrn_40_4_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 800

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)



balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 16, 32, 32])
# 2 feature: torch.Size([1, 64, 32, 32])
# 3 feature: torch.Size([1, 128, 16, 16])
# 4 feature: torch.Size([1, 256, 8, 8])
# 5 feature: torch.Size([1, 256])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─NetworkBlock: 1-2                      --
# |    └─Sequential: 2-1                   --
# |    |    └─BasicBlock: 3-1              47,264
# |    |    └─BasicBlock: 3-2              73,984
# |    |    └─BasicBlock: 3-3              73,984
# |    |    └─BasicBlock: 3-4              73,984
# |    |    └─BasicBlock: 3-5              73,984
# |    |    └─BasicBlock: 3-6              73,984
# ├─NetworkBlock: 1-3                      --
# |    └─Sequential: 2-2                   --
# |    |    └─BasicBlock: 3-7              229,760
# |    |    └─BasicBlock: 3-8              295,424
# |    |    └─BasicBlock: 3-9              295,424
# |    |    └─BasicBlock: 3-10             295,424
# |    |    └─BasicBlock: 3-11             295,424
# |    |    └─BasicBlock: 3-12             295,424
# ├─NetworkBlock: 1-4                      --
# |    └─Sequential: 2-3                   --
# |    |    └─BasicBlock: 3-13             918,272
# |    |    └─BasicBlock: 3-14             1,180,672
# |    |    └─BasicBlock: 3-15             1,180,672
# |    |    └─BasicBlock: 3-16             1,180,672
# |    |    └─BasicBlock: 3-17             1,180,672
# |    |    └─BasicBlock: 3-18             1,180,672
# ├─BatchNorm2d: 1-5                       512
# ├─ReLU: 1-6                              --
# ├─Linear: 1-7                            25,700
# =================================================================
# Total params: 8,972,340
# Trainable params: 8,972,340
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─NetworkBlock: 1-2                      --
# |    └─Sequential: 2-1                   --
# |    |    └─BasicBlock: 3-1              47,264
# |    |    └─BasicBlock: 3-2              73,984
# ├─NetworkBlock: 1-3                      --
# |    └─Sequential: 2-2                   --
# |    |    └─BasicBlock: 3-3              229,760
# |    |    └─BasicBlock: 3-4              295,424
# ├─NetworkBlock: 1-4                      --
# |    └─Sequential: 2-3                   --
# |    |    └─BasicBlock: 3-5              918,272
# |    |    └─BasicBlock: 3-6              1,180,672
# ├─BatchNorm2d: 1-5                       512
# ├─ReLU: 1-6                              --
# ├─Linear: 1-7                            25,700
# =================================================================
# Total params: 2,772,020
# Trainable params: 2,772,020
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 47,408
# |    |    └─SepConv: 3-2                 86,016
# |    |    └─SepConv: 3-3                 265,888
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       25,700
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 163,232
# |    |    └─SepConv: 3-6                 317,664
# |    |    └─SepConv: 3-7                 421,216
# |    |    └─AvgPool2d: 3-8               --
# |    └─Linear: 2-4                       25,700
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-9                 317,664
# |    |    └─SepConv: 3-10                421,216
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-6                       25,700
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-12                421,216
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-8                       25,700
# ├─FinalClassifier: 1-5                   --
# |    └─Linear: 2-9                       25,700
# =================================================================
# Total params: 2,590,020
# Trainable params: 2,590,020
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              47,408
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              86,016
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              265,888
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            25,700
# =================================================================
# Total params: 425,012
# Trainable params: 425,012
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              163,232
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              317,664
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              421,216
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            25,700
# =================================================================
# Total params: 927,812
# Trainable params: 927,812
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              317,664
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              421,216
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            25,700
# =================================================================
# Total params: 764,580
# Trainable params: 764,580
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              421,216
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            25,700
# =================================================================
# Total params: 446,916
# Trainable params: 446,916
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            25,700
# =================================================================
# Total params: 25,700
# Trainable params: 25,700
# Non-trainable params: 0
# =================================================================

# %%
print("WRN40-4 - WRN16-4")
model_t_params = 8972340
model_s_params = 2772020
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
model_s_ensemble1 = 432 + conv_distiller1
model_s_ensemble2 = 47264+73984 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 229760+295424 + conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 918272+1180672+512 + conv_distiller4 + model_s_ensemble3
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# WRN40-4 - WRN16-4
# Teacher model: 8972340 (100.000%)
# Student model: 2772020 (30.895%)
# Ensemble 1: 425444 (4.742%)
# Ensemble 2: 1474504 (16.434%)
# Ensemble 3: 2764268 (30.809%)
# Ensemble 4: 5310640 (59.189%)
# Final Ensemble: 5362040 (59.762%)

# %%
opt = {'model_t': 'wrn_16_10',
       'model_s': 'wrn_10_10',
       'path_t': './save/models/wrn_16_10_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 964

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)


balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 16, 32, 32])
# 2 feature: torch.Size([1, 160, 32, 32])
# 3 feature: torch.Size([1, 320, 16, 16])
# 4 feature: torch.Size([1, 640, 8, 8])
# 5 feature: torch.Size([1, 640])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─NetworkBlock: 1-2                      --
# |    └─Sequential: 2-1                   --
# |    |    └─BasicBlock: 3-1              256,352
# |    |    └─BasicBlock: 3-2              461,440
# ├─NetworkBlock: 1-3                      --
# |    └─Sequential: 2-2                   --
# |    |    └─BasicBlock: 3-3              1,434,560
# |    |    └─BasicBlock: 3-4              1,844,480
# ├─NetworkBlock: 1-4                      --
# |    └─Sequential: 2-3                   --
# |    |    └─BasicBlock: 3-5              5,736,320
# |    |    └─BasicBlock: 3-6              7,375,360
# ├─BatchNorm2d: 1-5                       1,280
# ├─ReLU: 1-6                              --
# ├─Linear: 1-7                            64,100
# =================================================================
# Total params: 17,174,324
# Trainable params: 17,174,324
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            432
# ├─NetworkBlock: 1-2                      --
# |    └─Sequential: 2-1                   --
# |    |    └─BasicBlock: 3-1              256,352
# ├─NetworkBlock: 1-3                      --
# |    └─Sequential: 2-2                   --
# |    |    └─BasicBlock: 3-2              1,434,560
# ├─NetworkBlock: 1-4                      --
# |    └─Sequential: 2-3                   --
# |    |    └─BasicBlock: 3-3              5,736,320
# ├─BatchNorm2d: 1-5                       1,280
# ├─ReLU: 1-6                              --
# ├─Linear: 1-7                            64,100
# =================================================================
# Total params: 7,493,044
# Trainable params: 7,493,044
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 57,084
# |    |    └─SepConv: 3-2                 103,564
# |    |    └─SepConv: 3-3                 691,116
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       64,100
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 475,404
# |    |    └─SepConv: 3-6                 940,204
# |    |    └─SepConv: 3-7                 1,251,564
# |    |    └─AvgPool2d: 3-8               --
# |    └─Linear: 2-4                       64,100
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-9                 940,204
# |    |    └─SepConv: 3-10                1,251,564
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-6                       64,100
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-12                1,251,564
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-8                       64,100
# ├─FinalClassifier: 1-5                   --
# |    └─Linear: 2-9                       64,100
# =================================================================
# Total params: 7,282,768
# Trainable params: 7,282,768
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              57,084
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              103,564
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              691,116
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            64,100
# =================================================================
# Total params: 915,864
# Trainable params: 915,864
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              475,404
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              940,204
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              1,251,564
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            64,100
# =================================================================
# Total params: 2,731,272
# Trainable params: 2,731,272
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              940,204
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              1,251,564
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            64,100
# =================================================================
# Total params: 2,255,868
# Trainable params: 2,255,868
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              1,251,564
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            64,100
# =================================================================
# Total params: 1,315,664
# Trainable params: 1,315,664
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            64,100
# =================================================================
# Total params: 64,100
# Trainable params: 64,100
# Non-trainable params: 0
# =================================================================

# %%
print("WRN16-10 - WRN10-10")
model_t_params = 17174324
model_s_params = 7493044
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
model_s_ensemble1 = 432 + conv_distiller1
model_s_ensemble2 = 98528+166272 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 516672+664320 + conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 2065536+2655744+768 + conv_distiller4 + model_s_ensemble3
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# WRN16-10 - WRN10-10
# Teacher model: 17174324 (100.000%)
# Student model: 7493044 (43.629%)
# Ensemble 1: 916296 (5.335%)
# Ensemble 2: 3912368 (22.780%)
# Ensemble 3: 7349228 (42.792%)
# Ensemble 4: 13386940 (77.947%)
# Final Ensemble: 14775812 (86.034%)

# %%
opt = {'model_t': 'vgg19',
       'model_s': 'vgg11',
       'path_t': './save/models/vgg19_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 1024

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)



balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 64, 32, 32])
# 2 feature: torch.Size([1, 128, 16, 16])
# 3 feature: torch.Size([1, 256, 8, 8])
# 4 feature: torch.Size([1, 512, 4, 4])
# 5 feature: torch.Size([1, 512, 4, 4])
# 6 feature: torch.Size([1, 512])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,792
# |    └─BatchNorm2d: 2-2                  128
# |    └─ReLU: 2-3                         --
# |    └─Conv2d: 2-4                       36,928
# |    └─BatchNorm2d: 2-5                  128
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-6                       73,856
# |    └─BatchNorm2d: 2-7                  256
# |    └─ReLU: 2-8                         --
# |    └─Conv2d: 2-9                       147,584
# |    └─BatchNorm2d: 2-10                 256
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-11                      295,168
# |    └─BatchNorm2d: 2-12                 512
# |    └─ReLU: 2-13                        --
# |    └─Conv2d: 2-14                      590,080
# |    └─BatchNorm2d: 2-15                 512
# |    └─ReLU: 2-16                        --
# |    └─Conv2d: 2-17                      590,080
# |    └─BatchNorm2d: 2-18                 512
# |    └─ReLU: 2-19                        --
# |    └─Conv2d: 2-20                      590,080
# |    └─BatchNorm2d: 2-21                 512
# ├─Sequential: 1-4                        --
# |    └─Conv2d: 2-22                      1,180,160
# |    └─BatchNorm2d: 2-23                 1,024
# |    └─ReLU: 2-24                        --
# |    └─Conv2d: 2-25                      2,359,808
# |    └─BatchNorm2d: 2-26                 1,024
# |    └─ReLU: 2-27                        --
# |    └─Conv2d: 2-28                      2,359,808
# |    └─BatchNorm2d: 2-29                 1,024
# |    └─ReLU: 2-30                        --
# |    └─Conv2d: 2-31                      2,359,808
# |    └─BatchNorm2d: 2-32                 1,024
# ├─Sequential: 1-5                        --
# |    └─Conv2d: 2-33                      2,359,808
# |    └─BatchNorm2d: 2-34                 1,024
# |    └─ReLU: 2-35                        --
# |    └─Conv2d: 2-36                      2,359,808
# |    └─BatchNorm2d: 2-37                 1,024
# |    └─ReLU: 2-38                        --
# |    └─Conv2d: 2-39                      2,359,808
# |    └─BatchNorm2d: 2-40                 1,024
# |    └─ReLU: 2-41                        --
# |    └─Conv2d: 2-42                      2,359,808
# |    └─BatchNorm2d: 2-43                 1,024
# ├─MaxPool2d: 1-6                         --
# ├─MaxPool2d: 1-7                         --
# ├─MaxPool2d: 1-8                         --
# ├─MaxPool2d: 1-9                         --
# ├─AdaptiveAvgPool2d: 1-10                --
# ├─Linear: 1-11                           51,300
# =================================================================
# Total params: 20,086,692
# Trainable params: 20,086,692
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,792
# |    └─BatchNorm2d: 2-2                  128
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-3                       73,856
# |    └─BatchNorm2d: 2-4                  256
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-5                       295,168
# |    └─BatchNorm2d: 2-6                  512
# |    └─ReLU: 2-7                         --
# |    └─Conv2d: 2-8                       590,080
# |    └─BatchNorm2d: 2-9                  512
# ├─Sequential: 1-4                        --
# |    └─Conv2d: 2-10                      1,180,160
# |    └─BatchNorm2d: 2-11                 1,024
# |    └─ReLU: 2-12                        --
# |    └─Conv2d: 2-13                      2,359,808
# |    └─BatchNorm2d: 2-14                 1,024
# ├─Sequential: 1-5                        --
# |    └─Conv2d: 2-15                      2,359,808
# |    └─BatchNorm2d: 2-16                 1,024
# |    └─ReLU: 2-17                        --
# |    └─Conv2d: 2-18                      2,359,808
# |    └─BatchNorm2d: 2-19                 1,024
# ├─MaxPool2d: 1-6                         --
# ├─MaxPool2d: 1-7                         --
# ├─MaxPool2d: 1-8                         --
# ├─MaxPool2d: 1-9                         --
# ├─AdaptiveAvgPool2d: 1-10                --
# ├─Linear: 1-11                           51,300
# =================================================================
# Total params: 9,277,284
# Trainable params: 9,277,284
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 208,704
# |    |    └─SepConv: 3-2                 406,144
# |    |    └─SepConv: 3-3                 801,024
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       51,300
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 406,144
# |    |    └─SepConv: 3-6                 801,024
# |    |    └─AvgPool2d: 3-7               --
# |    └─Linear: 2-4                       51,300
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-8                 801,024
# |    |    └─AvgPool2d: 3-9               --
# |    └─Linear: 2-6                       51,300
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-10                1,065,472
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-8                       51,300
# ├─TempDistiller: 1-5                     --
# |    └─Sequential: 2-9                   --
# |    |    └─SepConv: 3-12                1,065,472
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-10                      51,300
# ├─FinalClassifier: 1-6                   --
# |    └─Linear: 2-11                      51,300
# =================================================================
# Total params: 5,862,808
# Trainable params: 5,862,808
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              208,704
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              406,144
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              801,024
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 1,467,172
# Trainable params: 1,467,172
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              406,144
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              801,024
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 1,258,468
# Trainable params: 1,258,468
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              801,024
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 852,324
# Trainable params: 852,324
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              1,065,472
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 1,116,772
# Trainable params: 1,116,772
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              1,065,472
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 1,116,772
# Trainable params: 1,116,772
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            51,300
# =================================================================
# Total params: 51,300
# Trainable params: 51,300
# Non-trainable params: 0
# =================================================================

# %%
print("vgg19 - vgg11")
model_t_params = 20086692
model_s_params = 9277284
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
conv_distiller6 = params[5]
model_s_ensemble1 = 1792+128 + conv_distiller1
model_s_ensemble2 = 73856+ 256 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 295168+512 + 590080+ 512 +conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 1180160+1024+2359808+1024 + conv_distiller4 + model_s_ensemble3
model_s_ensemble5 = 2359808+1024+2359808+1024 + conv_distiller5 + model_s_ensemble4
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Ensemble 5: {} ({:.3f}%)".format(model_s_ensemble5, (model_s_ensemble5/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# vgg19 - vgg11
# Teacher model: 20086692 (100.000%)
# Student model: 9277284 (46.186%)
# Ensemble 1: 1469092 (7.314%)
# Ensemble 2: 2801672 (13.948%)
# Ensemble 3: 4540268 (22.603%)
# Ensemble 4: 9199056 (45.797%)
# Ensemble 5: 15037492 (74.863%)
# Final Ensemble: 15140092 (75.374%)

# %%
opt = {'model_t': 'vgg19',
       'model_s': 'vgg8',
       'path_t': './save/models/vgg19_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 480

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)


balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 64, 32, 32])
# 2 feature: torch.Size([1, 128, 16, 16])
# 3 feature: torch.Size([1, 256, 8, 8])
# 4 feature: torch.Size([1, 512, 4, 4])
# 5 feature: torch.Size([1, 512, 4, 4])
# 6 feature: torch.Size([1, 512])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,792
# |    └─BatchNorm2d: 2-2                  128
# |    └─ReLU: 2-3                         --
# |    └─Conv2d: 2-4                       36,928
# |    └─BatchNorm2d: 2-5                  128
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-6                       73,856
# |    └─BatchNorm2d: 2-7                  256
# |    └─ReLU: 2-8                         --
# |    └─Conv2d: 2-9                       147,584
# |    └─BatchNorm2d: 2-10                 256
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-11                      295,168
# |    └─BatchNorm2d: 2-12                 512
# |    └─ReLU: 2-13                        --
# |    └─Conv2d: 2-14                      590,080
# |    └─BatchNorm2d: 2-15                 512
# |    └─ReLU: 2-16                        --
# |    └─Conv2d: 2-17                      590,080
# |    └─BatchNorm2d: 2-18                 512
# |    └─ReLU: 2-19                        --
# |    └─Conv2d: 2-20                      590,080
# |    └─BatchNorm2d: 2-21                 512
# ├─Sequential: 1-4                        --
# |    └─Conv2d: 2-22                      1,180,160
# |    └─BatchNorm2d: 2-23                 1,024
# |    └─ReLU: 2-24                        --
# |    └─Conv2d: 2-25                      2,359,808
# |    └─BatchNorm2d: 2-26                 1,024
# |    └─ReLU: 2-27                        --
# |    └─Conv2d: 2-28                      2,359,808
# |    └─BatchNorm2d: 2-29                 1,024
# |    └─ReLU: 2-30                        --
# |    └─Conv2d: 2-31                      2,359,808
# |    └─BatchNorm2d: 2-32                 1,024
# ├─Sequential: 1-5                        --
# |    └─Conv2d: 2-33                      2,359,808
# |    └─BatchNorm2d: 2-34                 1,024
# |    └─ReLU: 2-35                        --
# |    └─Conv2d: 2-36                      2,359,808
# |    └─BatchNorm2d: 2-37                 1,024
# |    └─ReLU: 2-38                        --
# |    └─Conv2d: 2-39                      2,359,808
# |    └─BatchNorm2d: 2-40                 1,024
# |    └─ReLU: 2-41                        --
# |    └─Conv2d: 2-42                      2,359,808
# |    └─BatchNorm2d: 2-43                 1,024
# ├─MaxPool2d: 1-6                         --
# ├─MaxPool2d: 1-7                         --
# ├─MaxPool2d: 1-8                         --
# ├─MaxPool2d: 1-9                         --
# ├─AdaptiveAvgPool2d: 1-10                --
# ├─Linear: 1-11                           51,300
# =================================================================
# Total params: 20,086,692
# Trainable params: 20,086,692
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,792
# |    └─BatchNorm2d: 2-2                  128
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-3                       73,856
# |    └─BatchNorm2d: 2-4                  256
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-5                       295,168
# |    └─BatchNorm2d: 2-6                  512
# ├─Sequential: 1-4                        --
# |    └─Conv2d: 2-7                       1,180,160
# |    └─BatchNorm2d: 2-8                  1,024
# ├─Sequential: 1-5                        --
# |    └─Conv2d: 2-9                       2,359,808
# |    └─BatchNorm2d: 2-10                 1,024
# ├─MaxPool2d: 1-6                         --
# ├─MaxPool2d: 1-7                         --
# ├─MaxPool2d: 1-8                         --
# ├─MaxPool2d: 1-9                         --
# ├─AdaptiveAvgPool2d: 1-10                --
# ├─Linear: 1-11                           51,300
# =================================================================
# Total params: 3,965,028
# Trainable params: 3,965,028
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 98,272
# |    |    └─SepConv: 3-2                 191,264
# |    |    └─SepConv: 3-3                 377,248
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       51,300
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 191,264
# |    |    └─SepConv: 3-6                 377,248
# |    |    └─AvgPool2d: 3-7               --
# |    └─Linear: 2-4                       51,300
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-8                 377,248
# |    |    └─AvgPool2d: 3-9               --
# |    └─Linear: 2-6                       51,300
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-10                502,432
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-8                       51,300
# ├─TempDistiller: 1-5                     --
# |    └─Sequential: 2-9                   --
# |    |    └─SepConv: 3-12                502,432
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-10                      51,300
# ├─FinalClassifier: 1-6                   --
# |    └─Linear: 2-11                      51,300
# =================================================================
# Total params: 2,925,208
# Trainable params: 2,925,208
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              98,272
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              191,264
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              377,248
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 718,084
# Trainable params: 718,084
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              191,264
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              377,248
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 619,812
# Trainable params: 619,812
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              377,248
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 428,548
# Trainable params: 428,548
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              502,432
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 553,732
# Trainable params: 553,732
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              502,432
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 553,732
# Trainable params: 553,732
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            51,300
# =================================================================
# Total params: 51,300
# Trainable params: 51,300
# Non-trainable params: 0
# =================================================================

# %%
print("vgg19 - vgg8")
model_t_params = 20086692
model_s_params = 3965028
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
conv_distiller6 = params[5]
model_s_ensemble1 = 1792+128 + conv_distiller1
model_s_ensemble2 = 73856+ 256 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 295168+512 +conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 1180160+1024 + conv_distiller4 + model_s_ensemble3
model_s_ensemble5 = 2359808+1024 + conv_distiller5 + model_s_ensemble4
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Ensemble 5: {} ({:.3f}%)".format(model_s_ensemble5, (model_s_ensemble5/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# vgg19 - vgg8
# Teacher model: 20086692 (100.000%)
# Student model: 3965028 (19.740%)
# Ensemble 1: 720004 (3.584%)
# Ensemble 2: 1413928 (7.039%)
# Ensemble 3: 2138156 (10.645%)
# Ensemble 4: 3873072 (19.282%)
# Ensemble 5: 6787636 (33.792%)
# Final Ensemble: 6890236 (34.302%)

# %%
opt = {'model_t': 'vgg13',
       'model_s': 'vgg8',
       'path_t': './save/models/vgg13_best.pth',
       'cuda_visible_devices': 0,
       'trial': 0,
       'balance': .2,
       'temp': 3.0}

opt = Munch(opt)
MAX_CHANNEL = 480

class SepConv(nn.Module):
    def __init__(self, channel_in, channel_out, kernel_size=3, stride=2, padding=1, affine=True, max_channel=MAX_CHANNEL):
        super(SepConv, self).__init__()
        self.cadinality = channel_in * (max_channel / channel_in)
        inter_channel = int(self.cadinality)
        self.op = nn.Sequential(
            nn.Conv2d(channel_in, channel_in, kernel_size=kernel_size, stride=stride, padding=padding, groups=channel_in, bias=False),
            nn.Conv2d(channel_in, inter_channel, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(inter_channel, affine=affine),
            nn.ReLU(inplace=False),
            nn.Conv2d(inter_channel, inter_channel, kernel_size=kernel_size, stride=1, padding=padding, groups=inter_channel, bias=False),
            nn.Conv2d(inter_channel, channel_out, kernel_size=1, padding=0, bias=False),
            nn.BatchNorm2d(channel_out, affine=affine),
            nn.ReLU(inplace=False),
        )

    def forward(self, x):
        return self.op(x)


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


class TempDistiller(nn.Module):
    def __init__(self, in_channels, in_resolution, final_dim=64, num_classes=100):
        super(TempDistiller, self).__init__()
        self.module_list = []
        temp = in_resolution
        if temp <= 4:
            self.module_list.append(SepConv(
                channel_in=in_channels,
                channel_out = final_dim,
                stride=1))
        
        while temp > 4:
            self.module_list.append(SepConv(
                channel_in= in_channels,
                channel_out= final_dim if temp == 8 else in_channels*2 
            ))
#             print(temp)
            in_channels *= 2
            temp /= 2
        
        self.module_list.append(nn.AvgPool2d((4, 4), 1))
        self.module_list = nn.Sequential(*self.module_list)
        self.fc = nn.Linear(final_dim, num_classes)

    def forward(self, in_feat):
        out = self.module_list(in_feat)
        out = out.view(out.size(0), -1)
        feature = out
        out_fc = self.fc(feature)
        return out_fc, feature


## added in exp1_8
class FinalClassifier(nn.Module):
    def __init__(self, in_channels, final_dim=64, num_classes=100):
        super(FinalClassifier, self).__init__()
        self.fc2 = nn.Linear(in_channels, num_classes)
    
    def forward(self, x):
        out_fc = self.fc2(x)
        return out_fc, x


class SimpleMLP(nn.Module):
    def __init__(self, input_size, num_classes=100):
        super(SimpleMLP, self).__init__()

        self.simple = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.BatchNorm1d(128),
            nn.ReLU6(),
            nn.Linear(128, num_classes)
        )

    def forward(self, input):
        return self.simple(input)



balance = opt.balance
model_t = model_dict[opt.model_t](num_classes=100)
model_s = model_dict[opt.model_s](num_classes=100)
path_t = opt.path_t
# model_t.load_state_dict(torch.load(path_t)['model'])
model_t.eval()

if torch.cuda.is_available():
    model_s.cuda()
    model_t.cuda()
    
rand_ = torch.rand((1, 3, 32, 32), dtype=torch.float32).cuda()
out_feat, out_x = model_t(rand_, is_feat=True, preact=False)

# print("Batch size = {}".format(2))
for i, o in enumerate(out_feat):
    print("{} feature: {}".format(i+1, o.shape))
print("final feature: {}".format(out_x.shape))
final_dim = out_feat[-1].size(1)

conv_distiller = nn.ModuleList([TempDistiller(in_channels=f.size(1), in_resolution=f.size(2), final_dim=final_dim).cuda() for f in out_feat[:-1]])
conv_distiller.append(FinalClassifier(out_feat[-1].size(1), num_classes=n_cls))
MLP = SimpleMLP(out_feat[-1].size(1), 100).cuda()

trainable_models = nn.ModuleList([])
trainable_models.model_s = model_s
trainable_models.MLP = MLP
trainable_models.conv_distiller = conv_distiller

print("===============================model_t=====================================")
torchinfo.summary(model_t)
print("================================model_s===================================")
torchinfo.summary(model_s)
print("=============================conv_distiller================================")
torchinfo.summary(conv_distiller)
conv_param = 0
for p in conv_distiller.parameters():
    conv_param += np.prod(p.shape)

params = []
for conv in conv_distiller:
    param_num = 0
    for p in conv.parameters():
        param_num += np.prod(p.shape)
    params.append(param_num)
    torchinfo.summary(conv)
# Out:
# 1 feature: torch.Size([1, 64, 32, 32])
# 2 feature: torch.Size([1, 128, 16, 16])
# 3 feature: torch.Size([1, 256, 8, 8])
# 4 feature: torch.Size([1, 512, 4, 4])
# 5 feature: torch.Size([1, 512, 4, 4])
# 6 feature: torch.Size([1, 512])
# final feature: torch.Size([1, 100])
# ===============================model_t=====================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,792
# |    └─BatchNorm2d: 2-2                  128
# |    └─ReLU: 2-3                         --
# |    └─Conv2d: 2-4                       36,928
# |    └─BatchNorm2d: 2-5                  128
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-6                       73,856
# |    └─BatchNorm2d: 2-7                  256
# |    └─ReLU: 2-8                         --
# |    └─Conv2d: 2-9                       147,584
# |    └─BatchNorm2d: 2-10                 256
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-11                      295,168
# |    └─BatchNorm2d: 2-12                 512
# |    └─ReLU: 2-13                        --
# |    └─Conv2d: 2-14                      590,080
# |    └─BatchNorm2d: 2-15                 512
# ├─Sequential: 1-4                        --
# |    └─Conv2d: 2-16                      1,180,160
# |    └─BatchNorm2d: 2-17                 1,024
# |    └─ReLU: 2-18                        --
# |    └─Conv2d: 2-19                      2,359,808
# |    └─BatchNorm2d: 2-20                 1,024
# ├─Sequential: 1-5                        --
# |    └─Conv2d: 2-21                      2,359,808
# |    └─BatchNorm2d: 2-22                 1,024
# |    └─ReLU: 2-23                        --
# |    └─Conv2d: 2-24                      2,359,808
# |    └─BatchNorm2d: 2-25                 1,024
# ├─MaxPool2d: 1-6                         --
# ├─MaxPool2d: 1-7                         --
# ├─MaxPool2d: 1-8                         --
# ├─MaxPool2d: 1-9                         --
# ├─AdaptiveAvgPool2d: 1-10                --
# ├─Linear: 1-11                           51,300
# =================================================================
# Total params: 9,462,180
# Trainable params: 9,462,180
# Non-trainable params: 0
# =================================================================
# ================================model_s===================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,792
# |    └─BatchNorm2d: 2-2                  128
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-3                       73,856
# |    └─BatchNorm2d: 2-4                  256
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-5                       295,168
# |    └─BatchNorm2d: 2-6                  512
# ├─Sequential: 1-4                        --
# |    └─Conv2d: 2-7                       1,180,160
# |    └─BatchNorm2d: 2-8                  1,024
# ├─Sequential: 1-5                        --
# |    └─Conv2d: 2-9                       2,359,808
# |    └─BatchNorm2d: 2-10                 1,024
# ├─MaxPool2d: 1-6                         --
# ├─MaxPool2d: 1-7                         --
# ├─MaxPool2d: 1-8                         --
# ├─MaxPool2d: 1-9                         --
# ├─AdaptiveAvgPool2d: 1-10                --
# ├─Linear: 1-11                           51,300
# =================================================================
# Total params: 3,965,028
# Trainable params: 3,965,028
# Non-trainable params: 0
# =================================================================
# =============================conv_distiller================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─TempDistiller: 1-1                     --
# |    └─Sequential: 2-1                   --
# |    |    └─SepConv: 3-1                 98,272
# |    |    └─SepConv: 3-2                 191,264
# |    |    └─SepConv: 3-3                 377,248
# |    |    └─AvgPool2d: 3-4               --
# |    └─Linear: 2-2                       51,300
# ├─TempDistiller: 1-2                     --
# |    └─Sequential: 2-3                   --
# |    |    └─SepConv: 3-5                 191,264
# |    |    └─SepConv: 3-6                 377,248
# |    |    └─AvgPool2d: 3-7               --
# |    └─Linear: 2-4                       51,300
# ├─TempDistiller: 1-3                     --
# |    └─Sequential: 2-5                   --
# |    |    └─SepConv: 3-8                 377,248
# |    |    └─AvgPool2d: 3-9               --
# |    └─Linear: 2-6                       51,300
# ├─TempDistiller: 1-4                     --
# |    └─Sequential: 2-7                   --
# |    |    └─SepConv: 3-10                502,432
# |    |    └─AvgPool2d: 3-11              --
# |    └─Linear: 2-8                       51,300
# ├─TempDistiller: 1-5                     --
# |    └─Sequential: 2-9                   --
# |    |    └─SepConv: 3-12                502,432
# |    |    └─AvgPool2d: 3-13              --
# |    └─Linear: 2-10                      51,300
# ├─FinalClassifier: 1-6                   --
# |    └─Linear: 2-11                      51,300
# =================================================================
# Total params: 2,925,208
# Trainable params: 2,925,208
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              98,272
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              191,264
# |    └─SepConv: 2-3                      --
# |    |    └─Sequential: 3-3              377,248
# |    └─AvgPool2d: 2-4                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 718,084
# Trainable params: 718,084
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              191,264
# |    └─SepConv: 2-2                      --
# |    |    └─Sequential: 3-2              377,248
# |    └─AvgPool2d: 2-3                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 619,812
# Trainable params: 619,812
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              377,248
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 428,548
# Trainable params: 428,548
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              502,432
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 553,732
# Trainable params: 553,732
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─SepConv: 2-1                      --
# |    |    └─Sequential: 3-1              502,432
# |    └─AvgPool2d: 2-2                    --
# ├─Linear: 1-2                            51,300
# =================================================================
# Total params: 553,732
# Trainable params: 553,732
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            51,300
# =================================================================
# Total params: 51,300
# Trainable params: 51,300
# Non-trainable params: 0
# =================================================================

# %%
print("vgg13 - vgg8")
model_t_params = 9462180
model_s_params = 3965028
conv_distiller_params = conv_param # including final layer
conv_distiller1 = params[0]
conv_distiller2 = params[1]
conv_distiller3 = params[2]
conv_distiller4 = params[3]
conv_distiller5 = params[4]
conv_distiller6 = params[5]
model_s_ensemble1 = 1792+128 + conv_distiller1
model_s_ensemble2 = 73856+ 256 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 295168+512 +conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 1180160+1024 + conv_distiller4+ model_s_ensemble3
model_s_ensemble5 = 2359808+1024 + conv_distiller5+ model_s_ensemble4
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Ensemble 5: {} ({:.3f}%)".format(model_s_ensemble5, (model_s_ensemble5/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# vgg13 - vgg8
# Teacher model: 9462180 (100.000%)
# Student model: 3965028 (41.904%)
# Ensemble 1: 720004 (7.609%)
# Ensemble 2: 1413928 (14.943%)
# Ensemble 3: 2138156 (22.597%)
# Ensemble 4: 3873072 (40.932%)
# Ensemble 5: 6787636 (71.734%)
# Final Ensemble: 6890236 (72.819%)

# %%
print("wrn40_1 - wrn16_1")
model_t_params = 569780
model_s_params = 180916
conv_distiller_params = 546420 # including final layer
conv_distiller1 = 163988
conv_distiller2 = 163988
conv_distiller3 = 133572
conv_distiller4 = 78372
conv_distiller5 = 6500
model_s_ensemble1 = 432 + conv_distiller1
model_s_ensemble2 = 4672+4672 + conv_distiller2 + model_s_ensemble1
model_s_ensemble3 = 14432+18560 +conv_distiller3 + model_s_ensemble2
model_s_ensemble4 = 57536+73984 + model_s_ensemble3
final_ensemble = model_s_params + conv_distiller_params

print("Teacher model: {} ({:.3f}%)".format(model_t_params, 100))
print("Student model: {} ({:.3f}%)".format(model_s_params, (model_s_params/model_t_params)*100) )
print("Ensemble 1: {} ({:.3f}%)".format(model_s_ensemble1, (model_s_ensemble1/model_t_params)*100))
print("Ensemble 2: {} ({:.3f}%)".format(model_s_ensemble2, (model_s_ensemble2/model_t_params)*100))
print("Ensemble 3: {} ({:.3f}%)".format(model_s_ensemble3, (model_s_ensemble3/model_t_params)*100))
print("Ensemble 4: {} ({:.3f}%)".format(model_s_ensemble4, (model_s_ensemble4/model_t_params)*100))
print("Final Ensemble: {} ({:.3f}%)".format(final_ensemble, (final_ensemble/model_t_params)*100))
# Out:
# wrn40_1 - wrn16_1
# Teacher model: 569780 (100.000%)
# Student model: 180916 (31.752%)
# Ensemble 1: 164420 (28.857%)
# Ensemble 2: 337752 (59.278%)
# Ensemble 3: 504316 (88.511%)
# Ensemble 4: 635836 (111.593%)
# Final Ensemble: 727336 (127.652%)
